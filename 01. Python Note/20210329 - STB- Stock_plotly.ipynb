# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_stb.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df['Week_no']= df['datetime'].dt.week
df['Year_no']= df['datetime'].dt.year
df['Period'] = df['Year_no'].astype(str) + str("-") + df['Week_no'].astype(str)
df.head(3)
# Out:
# C:\Users\ngoho\AppData\Local\Temp/ipykernel_1108/3523027443.py:4: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#           <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# <Ticker>
# STB           20060712      12.4204      12.4204     12.4204       12.4204
# STB           20060713      12.7389      12.9777     12.7389       12.9777
# STB           20060714      13.2166      13.2166     12.8185       12.8185
#
#           <Volume>   datetime  Week_no  Year_no   Period
# <Ticker>
# STB         763190 2006-07-12       28     2006  2006-28
# STB        1694670 2006-07-13       28     2006  2006-28
# STB         935410 2006-07-14       28     2006  2006-28

# %%
df =df[['<CloseFixed>','datetime','<Volume>','Period','Year_no']]
df = df.head(15000)

# %%
#plot linechart for stock price
short_rolling = df['<CloseFixed>'].rolling(window=20).mean()

ema_long = df['<CloseFixed>'].ewm(span=50, adjust=False).mean()
ema_short = df['<CloseFixed>'].ewm(span=20, adjust=False).mean()
line_price = df['<CloseFixed>']
fig = go.Figure()
#px.line(df_hpg, x='datetime', y='<CloseFixed>', labels={'x':'Date', 'y':'Price'})

fig.update_layout(  autosize=False,   width=1200,    height=800)
fig.add_trace(go.Scatter(x=df.datetime, y=line_price, 
                        mode='lines', name='STB'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_short, 
                        mode='lines', name='Span 20-days EMA'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_long, 
                        mode='lines', name='Span 50-days EMA'))
# Out:
# <div>                            <div id="8920ecf5-1ee6-4119-87a5-a28fe85f4477" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8920ecf5-1ee6-4119-87a5-a28fe85f4477")) {                    Plotly.newPlot(                        "8920ecf5-1ee6-4119-87a5-a28fe85f4477",                        [{"mode":"lines","name":"STB","type":"scatter","x":["2006-07-12T00:00:00","2006-07-13T00:00:00","2006-07-14T00:00:00","2006-07-17T00:00:00","2006-07-18T00:00:00","2006-07-19T00:00:00","2006-07-20T00:00:00","2006-07-21T00:00:00","2006-07-24T00:00:00","2006-07-25T00:00:00","2006-07-26T00:00:00","2006-07-27T00:00:00","2006-07-28T00:00:00","2006-07-31T00:00:00","2006-08-01T00:00:00","2006-08-02T00:00:00","2006-08-03T00:00:00","2006-08-04T00:00:00","2006-08-07T00:00:
# ...

# %%
#px.violin(df_tips, y="tip", x="smoker", color="sex", box=True, points="all",
#          hover_data=df_tips.columns)

fig = go.Figure()
px.violin(df,x='Year_no',y='<CloseFixed>',box =True, points='all',
         hover_data=df.columns, title = 'STOCK Violin chart')
# Out:
# <div>                            <div id="82933f60-d963-49e3-8dc4-9ac1cddb1ac7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82933f60-d963-49e3-8dc4-9ac1cddb1ac7")) {                    Plotly.newPlot(                        "82933f60-d963-49e3-8dc4-9ac1cddb1ac7",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["2006-07-12T00:00:00",763190,"2006-28"],["2006-07-13T00:00:00",1694670,"2006-28"],["2006-07-14T00:00:00",935410,"2006-28"],["2006-07-17T00:00:00",1320510,"2006-29"],["2006-07-18T00:00:00",721380,"2006-29"],["2006-07-19T00:00:00",747410,"2006-29"],["2006-07-20T00:00:00",988420,"2006-29"],["2006-07-21T00:00:00",603240,"2006-29"],["2006-07-24T00:00:00",311780,"2006-30"],["2006-07-25T00:00:00",342530,"200
# ...

# %%
df.tail(3)
# Out:
#           <Close>   datetime  <Volume>   Period  Year_no
# <Ticker>
# STB          17.1 2015-05-07    238640  2015-19     2015
# STB          17.1 2015-05-06    355170  2015-19     2015
# STB          17.5 2015-05-05    752180  2015-19     2015

# %%
#HDFC_df[‘Day_Perc_Change’] = HDFC_df[‘Adj Close’].pct_change()*100
df['Daily_return']=df['<CloseFixed>'].pct_change()*100
df.dropna(axis = 0, inplace = True)
df.head(3)
# Out:
#           <CloseFixed>   datetime  <Volume>   Period  Year_no  Daily_return
# <Ticker>
# STB            12.9777 2006-07-13   1694670  2006-28     2006      4.486973
# STB            12.8185 2006-07-14    935410  2006-28     2006     -1.226720
# STB            12.3408 2006-07-17   1320510  2006-29     2006     -3.726645

# %%
fig = go.Figure()
px.line(df, x='datetime', y='Daily_return', labels={'x':'Date', 'y':'Daily_Return_%'})
# Out:
# <div>                            <div id="37dfc8fe-d6d0-48da-8323-1d4d0131218a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37dfc8fe-d6d0-48da-8323-1d4d0131218a")) {                    Plotly.newPlot(                        "37dfc8fe-d6d0-48da-8323-1d4d0131218a",                        [{"hovertemplate":"datetime=%{x}<br>Daily_return=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","showlegend":false,"type":"scattergl","x":["2006-07-13T00:00:00","2006-07-14T00:00:00","2006-07-17T00:00:00","2006-07-18T00:00:00","2006-07-19T00:00:00","2006-07-20T00:00:00","2006-07-21T00:00:00","2006-07-24T00:00:00","2006-07-25T00:00:00","2006-07-26T00:00:00","2006-07-27T00:00:00","2006-07-28T00:00:00","2006-0
# ...

# %%
df['Daily_return'].describe()
# Out:
# count    3912.000000
# mean        0.050746
# std         2.270595
# min        -6.984127
# 25%        -1.171886
# 50%         0.000000
# 75%         1.052756
# max         6.995885
# Name: Daily_return, dtype: float64

# %%
fig = go.Figure()
px.histogram(df, x="Daily_return",histnorm='percent')
#ff.create_distplot(df, group_labels)
# Out:
# <div>                            <div id="34f450be-ced0-4c12-9e86-fa0c68b871e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34f450be-ced0-4c12-9e86-fa0c68b871e8")) {                    Plotly.newPlot(                        "34f450be-ced0-4c12-9e86-fa0c68b871e8",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"Daily_return=%{x}<br>percent=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[4.486973044346398,-1.2267196806830194,-3.7266450832780795,-2.5808699598081186,-3.3113464145795635,4.7943084255260615,-1.960349710626763,-2.000385172532182,-4.761701327773881,-2.14327
# ...

# %%
df['<CloseFixed>'].describe()
# Out:
# count    3912.000000
# mean       13.866638
# std         5.381289
# min         5.027300
# 25%        10.429900
# 50%        12.550000
# 75%        15.471200
# max        35.850000
# Name: <CloseFixed>, dtype: float64

# %%
dfig = go.Figure()
px.histogram(df.head(60), x="Daily_return",histnorm='percent')
# Out:
# <div>                            <div id="a4cf83b4-a77e-4769-8e0b-9c3ca7a9b24b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4cf83b4-a77e-4769-8e0b-9c3ca7a9b24b")) {                    Plotly.newPlot(                        "a4cf83b4-a77e-4769-8e0b-9c3ca7a9b24b",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"Daily_return=%{x}<br>percent=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[4.486973044346398,-1.2267196806830194,-3.7266450832780795,-2.5808699598081186,-3.3113464145795635,4.7943084255260615,-1.960349710626763,-2.000385172532182,-4.761701327773881,-2.14327
# ...

# %%
df['Volumn'] = df['<Volume>']/1000000
Volumnshort_rolling = df['Volumn'].rolling(window=7).mean()

fig = go.Figure()

fig.update_layout(  autosize=False,   width=1200,    height=800)

fig.add_trace(go.Scatter(x=df.datetime, y=df['Daily_return'], 
                        mode='lines', name='Dailly_Retun'))

fig.add_trace(go.Scatter(x=df.datetime, y=df['Volumn'], 
                        mode='lines+markers', name='Volumn'))

fig.add_trace(go.Scatter(x=df.datetime, y=Volumnshort_rolling, 
                        mode='lines', name='Rolling_volumn'))

fig.add_trace(go.Scatter(x=df.datetime, y=df['<CloseFixed>'], 
                        mode='lines+markers', name='Price'))
# Out:
# <div>                            <div id="6ee077b8-d2bf-4226-bdb5-b92979eee5dc" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ee077b8-d2bf-4226-bdb5-b92979eee5dc")) {                    Plotly.newPlot(                        "6ee077b8-d2bf-4226-bdb5-b92979eee5dc",                        [{"mode":"lines","name":"Dailly_Retun","type":"scatter","x":["2006-07-13T00:00:00","2006-07-14T00:00:00","2006-07-17T00:00:00","2006-07-18T00:00:00","2006-07-19T00:00:00","2006-07-20T00:00:00","2006-07-21T00:00:00","2006-07-24T00:00:00","2006-07-25T00:00:00","2006-07-26T00:00:00","2006-07-27T00:00:00","2006-07-28T00:00:00","2006-07-31T00:00:00","2006-08-01T00:00:00","2006-08-02T00:00:00","2006-08-03T00:00:00","2006-08-04T00:00:00","2006-08-07T00:00:00","2006-08-
# ...

# %%
df['Volumn'].head(15).describe()
# Out:
# count    15.000000
# mean     38.939513
# std       8.521185
# min      25.317200
# 25%      32.425350
# 50%      41.485000
# 75%      45.927400
# max      51.625800
# Name: Volumn, dtype: float64

# %%
df['Volumn'].head(10).describe()
# Out:
# count    10.000000
# mean     38.879690
# std       6.666135
# min      29.032100
# 25%      35.192075
# 50%      39.216200
# 75%      44.327625
# max      47.546500
# Name: Volumn, dtype: float64
