# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_hvn.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df['Week_no']= df['datetime'].dt.week
df['Year_no']= df['datetime'].dt.year
df['Period'] = df['Year_no'].astype(str) + str("-") + df['Week_no'].astype(str)
df.head(3)
# Out:
#           <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# <Ticker>
# HVN           20210310        29.95         30.8       29.90         30.80
# HVN           20210309        30.00         30.4       29.80         30.15
# HVN           20210308        31.40         31.4       30.25         30.45
#
#           <Volume>  <Open>  <High>  <Low>  <Close>  <VolumeDeal>  <VolumeFB>  \
# <Ticker>
# HVN        1190200   29.95    30.8  29.90    30.80        540000       43900
# HVN         920400   30.00    30.4  29.80    30.15        779000       10300
# HVN        1311600   31.40    31.4  30.25    30.45        317000       18900
#
#           <VolumeFS>   datetime  Week_no  Year_no   Period
# <Ticker>
# HVN            18200 2021-03-10       10     2021  2021-10
# HVN            40500 2021-03-09       10     2021  2021-10
# HVN            50200 2021-03-08       10     2021  2021-10

# %%
df =df[['<Close>','datetime','<Volume>','Period','Year_no']]
df = df.head(900)

# %%
#plot linechart for HPG price
short_rolling = df['<Close>'].rolling(window=20).mean()

ema_long = df['<Close>'].ewm(span=50, adjust=False).mean()
ema_short = df['<Close>'].ewm(span=20, adjust=False).mean()
line_price = df['<Close>']
fig = go.Figure()
#px.line(df_hpg, x='datetime', y='<Close>', labels={'x':'Date', 'y':'Price'})

fig.add_trace(go.Scatter(x=df.datetime, y=line_price, 
                        mode='lines', name='HVN'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_short, 
                        mode='lines', name='Span 20-days EMA'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_long, 
                        mode='lines', name='Span 50-days EMA'))
# Out:
# <div>                            <div id="3032ae40-a839-4e70-b520-ff9c94e31f52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3032ae40-a839-4e70-b520-ff9c94e31f52")) {                    Plotly.newPlot(                        "3032ae40-a839-4e70-b520-ff9c94e31f52",                        [{"mode": "lines", "name": "HVN", "type": "scatter", "x": ["2021-03-10T00:00:00", "2021-03-09T00:00:00", "2021-03-08T00:00:00", "2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-19T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-05T00:00:00", "2021-02-04T00:00:00", "2021-02-03T00:00:00", "2021-02-02T00:00:00", "2021-02-01T00:00:00", "2021-01-29T00:00:00", "2021-01-28T00:00:00", "2021-01-27T00:00:00", "2021-01-26T00:00:00", "2021-01-25T00:00:00", "2021-01-22T00:00:00", "2021-01-21T00:00:00", "2021-01-20T00:00:00", "2021-01-19T00:00:00", "2021-01-18T00:00:00", "2021-01-15T00:00:00", "2021-01-14T00:00:00", "2021-01-13T00:00:00", "2021-01-12T00:00:00", "2021-01-11T00:00:00", "2021-01-08T00:00:00", "2021-01-07T00:00:00", "2021-01-06T00:00:00", "2021-01-05T00:00:00", "2021-01-04T00:00:00", "2020-12-31T00:00:00", "2020-12-30T00:00:00", "2020-12-29T00:00:00", "2020-12-28T00:00:00", "2020-12-25T00:00:00", "2020-12-24T00:00:00", "2020-12-23T00:00:00", "2020-12-22T00:00:00", "2020-12-21T00:00:00", "2020-12-18T00:00:00", "2020-12-17T00:00:00", "2020-12-16T00:00:00", "2020-12-15T00:00:00", "2020-12-14T00:00:00", "2020-12-11T00:00:00", "2020-12-10T00:00:00", "2020-12-09T00:00:00", "2020-12-08T00:00:00", "2020-12-07T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-20T00:00:00", "2020-11-19T00:00:00", "2020-11-18T00:00:00", "2020-11-17T00:00:00", "2020-11-16T00:00:00", "2020-11-13T00:00:00", "2020-11-12T00:00:00", "2020-11-11T00:00:00", "2020-11-10T00:00:00", "2020-11-09T00:00:00", "2020-11-06T00:00:00", "2020-11-05T00:00:00", "2020-11-04T00:00:00", "2020-11-03T00:00:00", "2020-11-02T00:00:00", "2020-10-30T00:00:00", "2020-10-29T00:00:00", "2020-10-28T00:00:00", "2020-10-27T00:00:00", "2020-10-26T00:00:00", "2020-10-23T00:00:00", "2020-10-22T00:00:00", "2020-10-21T00:00:00", "2020-10-20T00:00:00", "2020-10-19T00:00:00", "2020-10-16T00:00:00", "2020-10-15T00:00:00", "2020-10-14T00:00:00", "2020-10-13T00:00:00", "2020-10-12T00:00:00", "2020-10-09T00:00:00", "2020-10-08T00:00:00", "2020-10-07T00:00:00", "2020-10-06T00:00:00", "2020-10-05T00:00:00", "2020-10-02T00:00:00", "2020-10-01T00:00:00", "2020-09-30T00:00:00", "2020-09-29T00:00:00", "2020-09-28T00:00:00", "2020-09-25T00:00:00", "2020-09-24T00:00:00", "2020-09-23T00:00:00", "2020-09-22T00:00:00", "2020-09-21T00:00:00", "2020-09-18T00:00:00", "2020-09-17T00:00:00", "2020-09-16T00:00:00", "2020-09-15T00:00:00", "2020-09-14T00:00:00", "2020-09-11T00:00:00", "2020-09-10T00:00:00", "2020-09-09T00:00:00", "2020-09-08T00:00:00", "2020-09-07T00:00:00", "2020-09-04T00:00:00", "2020-09-03T00:00:00", "2020-09-01T00:00:00", "2020-08-31T00:00:00", "2020-08-28T00:00:00", "2020-08-27T00:00:00", "2020-08-26T00:00:00", "2020-08-25T00:00:00", "2020-08-24T00:00:00", "2020-08-21T00:00:00", "2020-08-20T00:00:00", "2020-08-19T00:00:00", "2020-08-18T00:00:00", "2020-08-17T00:00:00", "2020-08-14T00:00:00", "2020-08-13T00:00:00", "2020-08-12T00:00:00", "2020-08-11T00:00:00", "2020-08-10T00:00:00", "2020-08-07T00:00:00", "2020-08-06T00:00:00", "2020-0 ...

# %%
#px.violin(df_tips, y="tip", x="smoker", color="sex", box=True, points="all",
#          hover_data=df_tips.columns)

fig = go.Figure()
px.violin(df,x='Year_no',y='<Close>',box =True, points='all',
         hover_data=df.columns, title = 'HVN Violin chart')
# Out:
# <div>                            <div id="c0da8d55-13ef-4cd8-bf8f-a6954ef7b7de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0da8d55-13ef-4cd8-bf8f-a6954ef7b7de")) {                    Plotly.newPlot(                        "c0da8d55-13ef-4cd8-bf8f-a6954ef7b7de",                        [{"alignmentgroup": "True", "box": {"visible": true}, "customdata": [["2021-03-10T00:00:00", 1190200, "2021-10"], ["2021-03-09T00:00:00", 920400, "2021-10"], ["2021-03-08T00:00:00", 1311600, "2021-10"], ["2021-03-05T00:00:00", 1307800, "2021-9"], ["2021-03-04T00:00:00", 1615200, "2021-9"], ["2021-03-03T00:00:00", 1388500, "2021-9"], ["2021-03-02T00:00:00", 2010900, "2021-9"], ["2021-03-01T00:00:00", 2520200, "2021-9"], ["2021-02-26T00:00:00", 2176900, "2021-8"], ["2021-02-25T00:00:00", 1601700, "2021-8"], ["2021-02-24T00:00:00", 1925300, "2021-8"], ["2021-02-23T00:00:00", 1423300, "2021-8"], ["2021-02-22T00:00:00", 1278800, "2021-8"], ["2021-02-19T00:00:00", 1482400, "2021-7"], ["2021-02-18T00:00:00", 837900, "2021-7"], ["2021-02-17T00:00:00", 680200, "2021-7"], ["2021-02-09T00:00:00", 446800, "2021-6"], ["2021-02-08T00:00:00", 820100, "2021-6"], ["2021-02-05T00:00:00", 433300, "2021-5"], ["2021-02-04T00:00:00", 529900, "2021-5"], ["2021-02-03T00:00:00", 530100, "2021-5"], ["2021-02-02T00:00:00", 570500, "2021-5"], ["2021-02-01T00:00:00", 748100, "2021-5"], ["2021-01-29T00:00:00", 1063900, "2021-4"], ["2021-01-28T00:00:00", 1638500, "2021-4"], ["2021-01-27T00:00:00", 1005700, "2021-4"], ["2021-01-26T00:00:00", 905900, "2021-4"], ["2021-01-25T00:00:00", 651900, "2021-4"], ["2021-01-22T00:00:00", 1001700, "2021-3"], ["2021-01-21T00:00:00", 1008300, "2021-3"], ["2021-01-20T00:00:00", 1204200, "2021-3"], ["2021-01-19T00:00:00", 1713800, "2021-3"], ["2021-01-18T00:00:00", 1523800, "2021-3"], ["2021-01-15T00:00:00", 1423200, "2021-2"], ["2021-01-14T00:00:00", 1864700, "2021-2"], ["2021-01-13T00:00:00", 2170500, "2021-2"], ["2021-01-12T00:00:00", 2311500, "2021-2"], ["2021-01-11T00:00:00", 2407600, "2021-2"], ["2021-01-08T00:00:00", 2478600, "2021-1"], ["2021-01-07T00:00:00", 1668700, "2021-1"], ["2021-01-06T00:00:00", 1150000, "2021-1"], ["2021-01-05T00:00:00", 1310800, "2021-1"], ["2021-01-04T00:00:00", 1966600, "2021-1"], ["2020-12-31T00:00:00", 742640, "2020-53"], ["2020-12-30T00:00:00", 1104710, "2020-53"], ["2020-12-29T00:00:00", 1277340, "2020-53"], ["2020-12-28T00:00:00", 1556300, "2020-53"], ["2020-12-25T00:00:00", 1618240, "2020-52"], ["2020-12-24T00:00:00", 1157430, "2020-52"], ["2020-12-23T00:00:00", 1552100, "2020-52"], ["2020-12-22T00:00:00", 1207330, "2020-52"], ["2020-12-21T00:00:00", 1802010, "2020-52"], ["2020-12-18T00:00:00", 942350, "2020-51"], ["2020-12-17T00:00:00", 1586160, "2020-51"], ["2020-12-16T00:00:00", 1920380, "2020-51"], ["2020-12-15T00:00:00", 1228820, "2020-51"], ["2020-12-14T00:00:00", 1550880, "2020-51"], ["2020-12-11T00:00:00", 2357600, "2020-50"], ["2020-12-10T00:00:00", 683250, "2020-50"], ["2020-12-09T00:00:00", 793890, "2020-50"], ["2020-12-08T00:00:00", 539900, "2020-50"], ["2020-12-07T00:00:00", 563080, "2020-50"], ["2020-12-04T00:00:00", 483950, "2020-49"], ["2020-12-03T00:00:00", 587680, "2020-49"], ["2020-12-02T00:00:00", 807120, "2020-49"], ["2020-12-01T00:00:00", 790900, "2020-49"], ["2020-11-30T00:00:00", 806660, "2020-49"], ["2020-11-27T00:00:00", 334760, "2020-48"], ["2020-11-26T00:00:00", 449000, "2020-48"], ["2020-11-25T00:00:00", 657860, "2020-48"], ["2020-11-24T00:00:00", 982590, "2020-48"], ["2020-11-23T00:00:00", 673760, "2020-48"], ["2020-11-20T00:00:00", 977970, "2020-47"], ["2020-11-19T00:00:00", 763200, "2020-47"], ["2020-11-18T00:00:00", 2813620, "2020-47"], ["2020-11-17T00:00:00", 821070, "2020-47"], ["2020-11-16T00:00:00", 921370, "2020-47"], ["2020-1 ...
