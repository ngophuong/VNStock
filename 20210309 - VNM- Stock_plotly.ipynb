# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_vnm.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df['Week_no']= df['datetime'].dt.week
df['Year_no']= df['datetime'].dt.year
df['Period'] = df['Year_no'].astype(str) + str("-") + df['Week_no'].astype(str)
df.tail(3)
# Out:
#           <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# <Ticker>
# VNM           20060123       2.8688       2.8688      2.7891        2.7891
# VNM           20060120       2.9220       2.9220      2.8688        2.8688
# VNM           20060119       2.8157       2.8157      2.8157        2.8157
#
#           <Volume>  <Open>  <High>  <Low>  <Close>  <VolumeDeal>  <VolumeFB>  \
# <Ticker>
# VNM          81400    54.0    54.0   52.5     52.5             0           0
# VNM         157840    55.0    55.0   54.0     54.0             0           0
# VNM         109350    53.0    53.0   53.0     53.0             0           0
#
#           <VolumeFS>   datetime  Week_no  Year_no  Period
# <Ticker>
# VNM                0 2006-01-23        4     2006  2006-4
# VNM                0 2006-01-20        3     2006  2006-3
# VNM                0 2006-01-19        3     2006  2006-3

# %%
df =df[['<Close>','datetime','<Volume>','Period','Year_no']]
df = df.head(900)

# %%
#plot linechart for HPG price
short_rolling = df['<Close>'].rolling(window=20).mean()

ema_long = df['<Close>'].ewm(span=50, adjust=False).mean()
ema_short = df['<Close>'].ewm(span=20, adjust=False).mean()
line_price = df['<Close>']
fig = go.Figure()
#px.line(df_hpg, x='datetime', y='<Close>', labels={'x':'Date', 'y':'Price'})

fig.add_trace(go.Scatter(x=df.datetime, y=line_price, 
                        mode='lines', name='VNM'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_short, 
                        mode='lines', name='Span 20-days EMA'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_long, 
                        mode='lines', name='Span 50-days EMA'))
# Out:
# <div>                            <div id="be65f6ce-f7d5-4089-9353-89dbf7562e7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be65f6ce-f7d5-4089-9353-89dbf7562e7f")) {                    Plotly.newPlot(                        "be65f6ce-f7d5-4089-9353-89dbf7562e7f",                        [{"mode": "lines", "name": "VNM", "type": "scatter", "x": ["2021-03-09T00:00:00", "2021-03-08T00:00:00", "2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-19T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-05T00:00:00", "2021-02-04T00:00:00", "2021-02-03T00:00:00", "2021-02-02T00:00:00", "2021-02-01T00:00:00", "2021-01-29T00:00:00", "2021-01-28T00:00:00", "2021-01-27T00:00:00", "2021-01-26T00:00:00", "2021-01-25T00:00:00", "2021-01-22T00:00:00", "2021-01-21T00:00:00", "2021-01-20T00:00:00", "2021-01-19T00:00:00", "2021-01-18T00:00:00", "2021-01-15T00:00:00", "2021-01-14T00:00:00", "2021-01-13T00:00:00", "2021-01-12T00:00:00", "2021-01-11T00:00:00", "2021-01-08T00:00:00", "2021-01-07T00:00:00", "2021-01-06T00:00:00", "2021-01-05T00:00:00", "2021-01-04T00:00:00", "2020-12-31T00:00:00", "2020-12-30T00:00:00", "2020-12-29T00:00:00", "2020-12-28T00:00:00", "2020-12-25T00:00:00", "2020-12-24T00:00:00", "2020-12-23T00:00:00", "2020-12-22T00:00:00", "2020-12-21T00:00:00", "2020-12-18T00:00:00", "2020-12-17T00:00:00", "2020-12-16T00:00:00", "2020-12-15T00:00:00", "2020-12-14T00:00:00", "2020-12-11T00:00:00", "2020-12-10T00:00:00", "2020-12-09T00:00:00", "2020-12-08T00:00:00", "2020-12-07T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-20T00:00:00", "2020-11-19T00:00:00", "2020-11-18T00:00:00", "2020-11-17T00:00:00", "2020-11-16T00:00:00", "2020-11-13T00:00:00", "2020-11-12T00:00:00", "2020-11-11T00:00:00", "2020-11-10T00:00:00", "2020-11-09T00:00:00", "2020-11-06T00:00:00", "2020-11-05T00:00:00", "2020-11-04T00:00:00", "2020-11-03T00:00:00", "2020-11-02T00:00:00", "2020-10-30T00:00:00", "2020-10-29T00:00:00", "2020-10-28T00:00:00", "2020-10-27T00:00:00", "2020-10-26T00:00:00", "2020-10-23T00:00:00", "2020-10-22T00:00:00", "2020-10-21T00:00:00", "2020-10-20T00:00:00", "2020-10-19T00:00:00", "2020-10-16T00:00:00", "2020-10-15T00:00:00", "2020-10-14T00:00:00", "2020-10-13T00:00:00", "2020-10-12T00:00:00", "2020-10-09T00:00:00", "2020-10-08T00:00:00", "2020-10-07T00:00:00", "2020-10-06T00:00:00", "2020-10-05T00:00:00", "2020-10-02T00:00:00", "2020-10-01T00:00:00", "2020-09-30T00:00:00", "2020-09-29T00:00:00", "2020-09-28T00:00:00", "2020-09-25T00:00:00", "2020-09-24T00:00:00", "2020-09-23T00:00:00", "2020-09-22T00:00:00", "2020-09-21T00:00:00", "2020-09-18T00:00:00", "2020-09-17T00:00:00", "2020-09-16T00:00:00", "2020-09-15T00:00:00", "2020-09-14T00:00:00", "2020-09-11T00:00:00", "2020-09-10T00:00:00", "2020-09-09T00:00:00", "2020-09-08T00:00:00", "2020-09-07T00:00:00", "2020-09-04T00:00:00", "2020-09-03T00:00:00", "2020-09-01T00:00:00", "2020-08-31T00:00:00", "2020-08-28T00:00:00", "2020-08-27T00:00:00", "2020-08-26T00:00:00", "2020-08-25T00:00:00", "2020-08-24T00:00:00", "2020-08-21T00:00:00", "2020-08-20T00:00:00", "2020-08-19T00:00:00", "2020-08-18T00:00:00", "2020-08-17T00:00:00", "2020-08-14T00:00:00", "2020-08-13T00:00:00", "2020-08-12T00:00:00", "2020-08-11T00:00:00", "2020-08-10T00:00:00", "2020-08-07T00:00:00", "2020-08-06T00:00:00", "2020-08-05T00:00:00", "2020-0 ...

# %%
#px.violin(df_tips, y="tip", x="smoker", color="sex", box=True, points="all",
#          hover_data=df_tips.columns)

fig = go.Figure()
px.violin(df,x='Year_no',y='<Close>',box =True, points='all',
         hover_data=df.columns, title = 'VNM Violin chart')
# Out:
# <div>                            <div id="2eab677c-aa62-4706-8ae0-768816da351a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2eab677c-aa62-4706-8ae0-768816da351a")) {                    Plotly.newPlot(                        "2eab677c-aa62-4706-8ae0-768816da351a",                        [{"alignmentgroup": "True", "box": {"visible": true}, "customdata": [["2021-03-09T00:00:00", 4141900, "2021-10"], ["2021-03-08T00:00:00", 3208200, "2021-10"], ["2021-03-05T00:00:00", 4187600, "2021-9"], ["2021-03-04T00:00:00", 2755100, "2021-9"], ["2021-03-03T00:00:00", 2551300, "2021-9"], ["2021-03-02T00:00:00", 3050100, "2021-9"], ["2021-03-01T00:00:00", 2179000, "2021-9"], ["2021-02-26T00:00:00", 3357800, "2021-8"], ["2021-02-25T00:00:00", 4282900, "2021-8"], ["2021-02-24T00:00:00", 2801000, "2021-8"], ["2021-02-23T00:00:00", 3048400, "2021-8"], ["2021-02-22T00:00:00", 3006200, "2021-8"], ["2021-02-19T00:00:00", 2696500, "2021-7"], ["2021-02-18T00:00:00", 2847400, "2021-7"], ["2021-02-17T00:00:00", 2872300, "2021-7"], ["2021-02-09T00:00:00", 1931700, "2021-6"], ["2021-02-08T00:00:00", 4331600, "2021-6"], ["2021-02-05T00:00:00", 2231200, "2021-5"], ["2021-02-04T00:00:00", 1896800, "2021-5"], ["2021-02-03T00:00:00", 3056500, "2021-5"], ["2021-02-02T00:00:00", 3350900, "2021-5"], ["2021-02-01T00:00:00", 2934800, "2021-5"], ["2021-01-29T00:00:00", 4140500, "2021-4"], ["2021-01-28T00:00:00", 4565600, "2021-4"], ["2021-01-27T00:00:00", 3153800, "2021-4"], ["2021-01-26T00:00:00", 2596900, "2021-4"], ["2021-01-25T00:00:00", 2554800, "2021-4"], ["2021-01-22T00:00:00", 2429000, "2021-3"], ["2021-01-21T00:00:00", 2531200, "2021-3"], ["2021-01-20T00:00:00", 3363700, "2021-3"], ["2021-01-19T00:00:00", 3668300, "2021-3"], ["2021-01-18T00:00:00", 2624000, "2021-3"], ["2021-01-15T00:00:00", 2125700, "2021-2"], ["2021-01-14T00:00:00", 3680400, "2021-2"], ["2021-01-13T00:00:00", 2521600, "2021-2"], ["2021-01-12T00:00:00", 2344900, "2021-2"], ["2021-01-11T00:00:00", 4603900, "2021-2"], ["2021-01-08T00:00:00", 3323000, "2021-1"], ["2021-01-07T00:00:00", 2453000, "2021-1"], ["2021-01-06T00:00:00", 2823100, "2021-1"], ["2021-01-05T00:00:00", 4013900, "2021-1"], ["2021-01-04T00:00:00", 2299600, "2021-1"], ["2020-12-31T00:00:00", 993810, "2020-53"], ["2020-12-30T00:00:00", 1856600, "2020-53"], ["2020-12-29T00:00:00", 1299700, "2020-53"], ["2020-12-28T00:00:00", 2305300, "2020-53"], ["2020-12-25T00:00:00", 1755510, "2020-52"], ["2020-12-24T00:00:00", 2511360, "2020-52"], ["2020-12-23T00:00:00", 2432590, "2020-52"], ["2020-12-22T00:00:00", 2266760, "2020-52"], ["2020-12-21T00:00:00", 2341080, "2020-52"], ["2020-12-18T00:00:00", 3342900, "2020-51"], ["2020-12-17T00:00:00", 2951870, "2020-51"], ["2020-12-16T00:00:00", 2106480, "2020-51"], ["2020-12-15T00:00:00", 4572910, "2020-51"], ["2020-12-14T00:00:00", 2535300, "2020-51"], ["2020-12-11T00:00:00", 2297940, "2020-50"], ["2020-12-10T00:00:00", 6077770, "2020-50"], ["2020-12-09T00:00:00", 1701940, "2020-50"], ["2020-12-08T00:00:00", 1468350, "2020-50"], ["2020-12-07T00:00:00", 1970400, "2020-50"], ["2020-12-04T00:00:00", 1571130, "2020-49"], ["2020-12-03T00:00:00", 1108730, "2020-49"], ["2020-12-02T00:00:00", 1332460, "2020-49"], ["2020-12-01T00:00:00", 2493230, "2020-49"], ["2020-11-30T00:00:00", 2687040, "2020-49"], ["2020-11-27T00:00:00", 2823860, "2020-48"], ["2020-11-26T00:00:00", 1490270, "2020-48"], ["2020-11-25T00:00:00", 2190900, "2020-48"], ["2020-11-24T00:00:00", 1937130, "2020-48"], ["2020-11-23T00:00:00", 2104330, "2020-48"], ["2020-11-20T00:00:00", 2801420, "2020-47"], ["2020-11-19T00:00:00", 3140680, "2020-47"], ["2020-11-18T00:00:00", 3396750, "2020-47"], ["2020-11-17T00:00:00", 1648330, "2020-47"], ["2020-11-16T00:00:00", 2571160, "2020-47"], ["2020-11-13T00:00:00" ...
