# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_pnj.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df['Week_no']= df['datetime'].dt.week
df['Year_no']= df['datetime'].dt.year
df['Period'] = df['Year_no'].astype(str) + str("-") + df['Week_no'].astype(str)
df.tail(3)
# Out:
#           <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# <Ticker>
# PNJ           20090325       4.7409       4.7409      4.7409        4.7409
# PNJ           20090324       4.5323       4.5323      4.5323        4.5323
# PNJ           20090323       4.3237       4.3237      4.3237        4.3237
#
#           <Volume>  <Open>  <High>  <Low>  <Close>  <VolumeDeal>  <VolumeFB>  \
# <Ticker>
# PNJ           2200    50.0    50.0   50.0     50.0         23900           0
# PNJ            380    47.8    47.8   47.8     47.8        106000           0
# PNJ          35010    45.6    45.6   45.6     45.6             0       10000
#
#           <VolumeFS>   datetime  Week_no  Year_no   Period
# <Ticker>
# PNJ                0 2009-03-25       13     2009  2009-13
# PNJ                0 2009-03-24       13     2009  2009-13
# PNJ                0 2009-03-23       13     2009  2009-13

# %%
df =df[['<Close>','datetime','<Volume>','Period','Year_no']]
df = df.head(900)

# %%
#plot linechart for HPG price
short_rolling = df['<Close>'].rolling(window=20).mean()

ema_long = df['<Close>'].ewm(span=50, adjust=False).mean()
ema_short = df['<Close>'].ewm(span=20, adjust=False).mean()
line_price = df['<Close>']
fig = go.Figure()
#px.line(df_hpg, x='datetime', y='<Close>', labels={'x':'Date', 'y':'Price'})

fig.add_trace(go.Scatter(x=df.datetime, y=line_price, 
                        mode='lines', name='PNJ'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_short, 
                        mode='lines', name='Span 20-days EMA'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_long, 
                        mode='lines', name='Span 50-days EMA'))
# Out:
# <div>                            <div id="75cc4f0d-16e7-45ad-bda2-6a57eae8dd6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75cc4f0d-16e7-45ad-bda2-6a57eae8dd6d")) {                    Plotly.newPlot(                        "75cc4f0d-16e7-45ad-bda2-6a57eae8dd6d",                        [{"mode": "lines", "name": "PNJ", "type": "scatter", "x": ["2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-19T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-05T00:00:00", "2021-02-04T00:00:00", "2021-02-03T00:00:00", "2021-02-02T00:00:00", "2021-02-01T00:00:00", "2021-01-29T00:00:00", "2021-01-28T00:00:00", "2021-01-27T00:00:00", "2021-01-26T00:00:00", "2021-01-25T00:00:00", "2021-01-22T00:00:00", "2021-01-21T00:00:00", "2021-01-20T00:00:00", "2021-01-19T00:00:00", "2021-01-18T00:00:00", "2021-01-15T00:00:00", "2021-01-14T00:00:00", "2021-01-13T00:00:00", "2021-01-12T00:00:00", "2021-01-11T00:00:00", "2021-01-08T00:00:00", "2021-01-07T00:00:00", "2021-01-06T00:00:00", "2021-01-05T00:00:00", "2021-01-04T00:00:00", "2020-12-31T00:00:00", "2020-12-30T00:00:00", "2020-12-29T00:00:00", "2020-12-28T00:00:00", "2020-12-25T00:00:00", "2020-12-24T00:00:00", "2020-12-23T00:00:00", "2020-12-22T00:00:00", "2020-12-21T00:00:00", "2020-12-18T00:00:00", "2020-12-17T00:00:00", "2020-12-16T00:00:00", "2020-12-15T00:00:00", "2020-12-14T00:00:00", "2020-12-11T00:00:00", "2020-12-10T00:00:00", "2020-12-09T00:00:00", "2020-12-08T00:00:00", "2020-12-07T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-20T00:00:00", "2020-11-19T00:00:00", "2020-11-18T00:00:00", "2020-11-17T00:00:00", "2020-11-16T00:00:00", "2020-11-13T00:00:00", "2020-11-12T00:00:00", "2020-11-11T00:00:00", "2020-11-10T00:00:00", "2020-11-09T00:00:00", "2020-11-06T00:00:00", "2020-11-05T00:00:00", "2020-11-04T00:00:00", "2020-11-03T00:00:00", "2020-11-02T00:00:00", "2020-10-30T00:00:00", "2020-10-29T00:00:00", "2020-10-28T00:00:00", "2020-10-27T00:00:00", "2020-10-26T00:00:00", "2020-10-23T00:00:00", "2020-10-22T00:00:00", "2020-10-21T00:00:00", "2020-10-20T00:00:00", "2020-10-19T00:00:00", "2020-10-16T00:00:00", "2020-10-15T00:00:00", "2020-10-14T00:00:00", "2020-10-13T00:00:00", "2020-10-12T00:00:00", "2020-10-09T00:00:00", "2020-10-08T00:00:00", "2020-10-07T00:00:00", "2020-10-06T00:00:00", "2020-10-05T00:00:00", "2020-10-02T00:00:00", "2020-10-01T00:00:00", "2020-09-30T00:00:00", "2020-09-29T00:00:00", "2020-09-28T00:00:00", "2020-09-25T00:00:00", "2020-09-24T00:00:00", "2020-09-23T00:00:00", "2020-09-22T00:00:00", "2020-09-21T00:00:00", "2020-09-18T00:00:00", "2020-09-17T00:00:00", "2020-09-16T00:00:00", "2020-09-15T00:00:00", "2020-09-14T00:00:00", "2020-09-11T00:00:00", "2020-09-10T00:00:00", "2020-09-09T00:00:00", "2020-09-08T00:00:00", "2020-09-07T00:00:00", "2020-09-04T00:00:00", "2020-09-03T00:00:00", "2020-09-01T00:00:00", "2020-08-31T00:00:00", "2020-08-28T00:00:00", "2020-08-27T00:00:00", "2020-08-26T00:00:00", "2020-08-25T00:00:00", "2020-08-24T00:00:00", "2020-08-21T00:00:00", "2020-08-20T00:00:00", "2020-08-19T00:00:00", "2020-08-18T00:00:00", "2020-08-17T00:00:00", "2020-08-14T00:00:00", "2020-08-13T00:00:00", "2020-08-12T00:00:00", "2020-08-11T00:00:00", "2020-08-10T00:00:00", "2020-08-07T00:00:00", "2020-08-06T00:00:00", "2020-08-05T00:00:00", "2020-08-04T00:00:00", "2020-08-03T00:00:00", "2020-0 ...

# %%
#px.violin(df_tips, y="tip", x="smoker", color="sex", box=True, points="all",
#          hover_data=df_tips.columns)

fig = go.Figure()
px.violin(df,x='Year_no',y='<Close>',box =True, points='all',
         hover_data=df.columns, title = 'PNJ Violin chart')
# Out:
# <div>                            <div id="59ebbdde-dfbd-4af7-8f7b-f7298a87c698" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59ebbdde-dfbd-4af7-8f7b-f7298a87c698")) {                    Plotly.newPlot(                        "59ebbdde-dfbd-4af7-8f7b-f7298a87c698",                        [{"alignmentgroup": "True", "box": {"visible": true}, "customdata": [["2021-03-05T00:00:00", 290000, "2021-9"], ["2021-03-04T00:00:00", 371100, "2021-9"], ["2021-03-03T00:00:00", 526100, "2021-9"], ["2021-03-02T00:00:00", 317600, "2021-9"], ["2021-03-01T00:00:00", 482000, "2021-9"], ["2021-02-26T00:00:00", 579400, "2021-8"], ["2021-02-25T00:00:00", 427100, "2021-8"], ["2021-02-24T00:00:00", 562400, "2021-8"], ["2021-02-23T00:00:00", 1045500, "2021-8"], ["2021-02-22T00:00:00", 665700, "2021-8"], ["2021-02-19T00:00:00", 459900, "2021-7"], ["2021-02-18T00:00:00", 869200, "2021-7"], ["2021-02-17T00:00:00", 837600, "2021-7"], ["2021-02-09T00:00:00", 522600, "2021-6"], ["2021-02-08T00:00:00", 644100, "2021-6"], ["2021-02-05T00:00:00", 620600, "2021-5"], ["2021-02-04T00:00:00", 649600, "2021-5"], ["2021-02-03T00:00:00", 639700, "2021-5"], ["2021-02-02T00:00:00", 599800, "2021-5"], ["2021-02-01T00:00:00", 600700, "2021-5"], ["2021-01-29T00:00:00", 901800, "2021-4"], ["2021-01-28T00:00:00", 1106100, "2021-4"], ["2021-01-27T00:00:00", 663300, "2021-4"], ["2021-01-26T00:00:00", 595600, "2021-4"], ["2021-01-25T00:00:00", 1264300, "2021-4"], ["2021-01-22T00:00:00", 716000, "2021-3"], ["2021-01-21T00:00:00", 419300, "2021-3"], ["2021-01-20T00:00:00", 978200, "2021-3"], ["2021-01-19T00:00:00", 857500, "2021-3"], ["2021-01-18T00:00:00", 641400, "2021-3"], ["2021-01-15T00:00:00", 530900, "2021-2"], ["2021-01-14T00:00:00", 476100, "2021-2"], ["2021-01-13T00:00:00", 448100, "2021-2"], ["2021-01-12T00:00:00", 561700, "2021-2"], ["2021-01-11T00:00:00", 579000, "2021-2"], ["2021-01-08T00:00:00", 554000, "2021-1"], ["2021-01-07T00:00:00", 582700, "2021-1"], ["2021-01-06T00:00:00", 721900, "2021-1"], ["2021-01-05T00:00:00", 534700, "2021-1"], ["2021-01-04T00:00:00", 743400, "2021-1"], ["2020-12-31T00:00:00", 681980, "2020-53"], ["2020-12-30T00:00:00", 1345200, "2020-53"], ["2020-12-29T00:00:00", 1003660, "2020-53"], ["2020-12-28T00:00:00", 735450, "2020-53"], ["2020-12-25T00:00:00", 571620, "2020-52"], ["2020-12-24T00:00:00", 497430, "2020-52"], ["2020-12-23T00:00:00", 505640, "2020-52"], ["2020-12-22T00:00:00", 957080, "2020-52"], ["2020-12-21T00:00:00", 676290, "2020-52"], ["2020-12-18T00:00:00", 582740, "2020-51"], ["2020-12-17T00:00:00", 1289500, "2020-51"], ["2020-12-16T00:00:00", 636190, "2020-51"], ["2020-12-15T00:00:00", 867800, "2020-51"], ["2020-12-14T00:00:00", 533210, "2020-51"], ["2020-12-11T00:00:00", 1089180, "2020-50"], ["2020-12-10T00:00:00", 964410, "2020-50"], ["2020-12-09T00:00:00", 566430, "2020-50"], ["2020-12-08T00:00:00", 727940, "2020-50"], ["2020-12-07T00:00:00", 594550, "2020-50"], ["2020-12-04T00:00:00", 904440, "2020-49"], ["2020-12-03T00:00:00", 942980, "2020-49"], ["2020-12-02T00:00:00", 1002760, "2020-49"], ["2020-12-01T00:00:00", 890610, "2020-49"], ["2020-11-30T00:00:00", 1194810, "2020-49"], ["2020-11-27T00:00:00", 1255000, "2020-48"], ["2020-11-26T00:00:00", 816530, "2020-48"], ["2020-11-25T00:00:00", 1091650, "2020-48"], ["2020-11-24T00:00:00", 1122210, "2020-48"], ["2020-11-23T00:00:00", 1959950, "2020-48"], ["2020-11-20T00:00:00", 646460, "2020-47"], ["2020-11-19T00:00:00", 1323020, "2020-47"], ["2020-11-18T00:00:00", 780440, "2020-47"], ["2020-11-17T00:00:00", 887650, "2020-47"], ["2020-11-16T00:00:00", 1409570, "2020-47"], ["2020-11-13T00:00:00", 631180, "2020-46"], ["2020-11-12T00:00:00", 889610, "2020-46"], ["2020-11-11T00:00:00", 1709780, "2020-46"], ["2020-11-10T00:00:00", 1116100, "202 ...
