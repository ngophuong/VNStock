# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_vjc.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df['Week_no']= df['datetime'].dt.week
df['Year_no']= df['datetime'].dt.year
df['Period'] = df['Year_no'].astype(str) + str("-") + df['Week_no'].astype(str)
df.head(3)
# Out:
#           <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# <Ticker>
# VJC           20210310        134.9        135.5       133.6         135.5
# VJC           20210309        135.6        135.6       133.0         134.9
# VJC           20210308        137.2        137.3       134.2         136.0
#
#           <Volume>  <Open>  <High>  <Low>  <Close>  <VolumeDeal>  <VolumeFB>  \
# <Ticker>
# VJC         767100   134.9   135.5  133.6    135.5             0      187600
# VJC         476800   135.6   135.6  133.0    134.9             0        3700
# VJC         493900   137.2   137.3  134.2    136.0             0       10400
#
#           <VolumeFS>   datetime  Week_no  Year_no   Period
# <Ticker>
# VJC           134900 2021-03-10       10     2021  2021-10
# VJC            41300 2021-03-09       10     2021  2021-10
# VJC            59500 2021-03-08       10     2021  2021-10

# %%
df =df[['<Close>','datetime','<Volume>','Period','Year_no']]
df = df.head(900)

# %%
#plot linechart for HPG price
short_rolling = df['<Close>'].rolling(window=20).mean()

ema_long = df['<Close>'].ewm(span=50, adjust=False).mean()
ema_short = df['<Close>'].ewm(span=20, adjust=False).mean()
line_price = df['<Close>']
fig = go.Figure()
#px.line(df_hpg, x='datetime', y='<Close>', labels={'x':'Date', 'y':'Price'})

fig.add_trace(go.Scatter(x=df.datetime, y=line_price, 
                        mode='lines', name='VJC'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_short, 
                        mode='lines', name='Span 20-days EMA'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_long, 
                        mode='lines', name='Span 50-days EMA'))
# Out:
# <div>                            <div id="69f44fc0-d6de-4618-ac93-9d1a48918d1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69f44fc0-d6de-4618-ac93-9d1a48918d1a")) {                    Plotly.newPlot(                        "69f44fc0-d6de-4618-ac93-9d1a48918d1a",                        [{"mode": "lines", "name": "VJC", "type": "scatter", "x": ["2021-03-10T00:00:00", "2021-03-09T00:00:00", "2021-03-08T00:00:00", "2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-19T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-05T00:00:00", "2021-02-04T00:00:00", "2021-02-03T00:00:00", "2021-02-02T00:00:00", "2021-02-01T00:00:00", "2021-01-29T00:00:00", "2021-01-28T00:00:00", "2021-01-27T00:00:00", "2021-01-26T00:00:00", "2021-01-25T00:00:00", "2021-01-22T00:00:00", "2021-01-21T00:00:00", "2021-01-20T00:00:00", "2021-01-19T00:00:00", "2021-01-18T00:00:00", "2021-01-15T00:00:00", "2021-01-14T00:00:00", "2021-01-13T00:00:00", "2021-01-12T00:00:00", "2021-01-11T00:00:00", "2021-01-08T00:00:00", "2021-01-07T00:00:00", "2021-01-06T00:00:00", "2021-01-05T00:00:00", "2021-01-04T00:00:00", "2020-12-31T00:00:00", "2020-12-30T00:00:00", "2020-12-29T00:00:00", "2020-12-28T00:00:00", "2020-12-25T00:00:00", "2020-12-24T00:00:00", "2020-12-23T00:00:00", "2020-12-22T00:00:00", "2020-12-21T00:00:00", "2020-12-18T00:00:00", "2020-12-17T00:00:00", "2020-12-16T00:00:00", "2020-12-15T00:00:00", "2020-12-14T00:00:00", "2020-12-11T00:00:00", "2020-12-10T00:00:00", "2020-12-09T00:00:00", "2020-12-08T00:00:00", "2020-12-07T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-20T00:00:00", "2020-11-19T00:00:00", "2020-11-18T00:00:00", "2020-11-17T00:00:00", "2020-11-16T00:00:00", "2020-11-13T00:00:00", "2020-11-12T00:00:00", "2020-11-11T00:00:00", "2020-11-10T00:00:00", "2020-11-09T00:00:00", "2020-11-06T00:00:00", "2020-11-05T00:00:00", "2020-11-04T00:00:00", "2020-11-03T00:00:00", "2020-11-02T00:00:00", "2020-10-30T00:00:00", "2020-10-29T00:00:00", "2020-10-28T00:00:00", "2020-10-27T00:00:00", "2020-10-26T00:00:00", "2020-10-23T00:00:00", "2020-10-22T00:00:00", "2020-10-21T00:00:00", "2020-10-20T00:00:00", "2020-10-19T00:00:00", "2020-10-16T00:00:00", "2020-10-15T00:00:00", "2020-10-14T00:00:00", "2020-10-13T00:00:00", "2020-10-12T00:00:00", "2020-10-09T00:00:00", "2020-10-08T00:00:00", "2020-10-07T00:00:00", "2020-10-06T00:00:00", "2020-10-05T00:00:00", "2020-10-02T00:00:00", "2020-10-01T00:00:00", "2020-09-30T00:00:00", "2020-09-29T00:00:00", "2020-09-28T00:00:00", "2020-09-25T00:00:00", "2020-09-24T00:00:00", "2020-09-23T00:00:00", "2020-09-22T00:00:00", "2020-09-21T00:00:00", "2020-09-18T00:00:00", "2020-09-17T00:00:00", "2020-09-16T00:00:00", "2020-09-15T00:00:00", "2020-09-14T00:00:00", "2020-09-11T00:00:00", "2020-09-10T00:00:00", "2020-09-09T00:00:00", "2020-09-08T00:00:00", "2020-09-07T00:00:00", "2020-09-04T00:00:00", "2020-09-03T00:00:00", "2020-09-01T00:00:00", "2020-08-31T00:00:00", "2020-08-28T00:00:00", "2020-08-27T00:00:00", "2020-08-26T00:00:00", "2020-08-25T00:00:00", "2020-08-24T00:00:00", "2020-08-21T00:00:00", "2020-08-20T00:00:00", "2020-08-19T00:00:00", "2020-08-18T00:00:00", "2020-08-17T00:00:00", "2020-08-14T00:00:00", "2020-08-13T00:00:00", "2020-08-12T00:00:00", "2020-08-11T00:00:00", "2020-08-10T00:00:00", "2020-08-07T00:00:00", "2020-08-06T00:00:00", "2020-0 ...

# %%
#px.violin(df_tips, y="tip", x="smoker", color="sex", box=True, points="all",
#          hover_data=df_tips.columns)

fig = go.Figure()
px.violin(df,x='Year_no',y='<Close>',box =True, points='all',
         hover_data=df.columns, title = 'VJC Violin chart')
# Out:
# <div>                            <div id="108c582b-8587-4cb3-a943-4daa55835ce6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("108c582b-8587-4cb3-a943-4daa55835ce6")) {                    Plotly.newPlot(                        "108c582b-8587-4cb3-a943-4daa55835ce6",                        [{"alignmentgroup": "True", "box": {"visible": true}, "customdata": [["2021-03-10T00:00:00", 767100, "2021-10"], ["2021-03-09T00:00:00", 476800, "2021-10"], ["2021-03-08T00:00:00", 493900, "2021-10"], ["2021-03-05T00:00:00", 490100, "2021-9"], ["2021-03-04T00:00:00", 353700, "2021-9"], ["2021-03-03T00:00:00", 704400, "2021-9"], ["2021-03-02T00:00:00", 802800, "2021-9"], ["2021-03-01T00:00:00", 663800, "2021-9"], ["2021-02-26T00:00:00", 772100, "2021-8"], ["2021-02-25T00:00:00", 839300, "2021-8"], ["2021-02-24T00:00:00", 545400, "2021-8"], ["2021-02-23T00:00:00", 1228400, "2021-8"], ["2021-02-22T00:00:00", 577000, "2021-8"], ["2021-02-19T00:00:00", 536500, "2021-7"], ["2021-02-18T00:00:00", 608400, "2021-7"], ["2021-02-17T00:00:00", 618600, "2021-7"], ["2021-02-09T00:00:00", 660800, "2021-6"], ["2021-02-08T00:00:00", 1310700, "2021-6"], ["2021-02-05T00:00:00", 496400, "2021-5"], ["2021-02-04T00:00:00", 604900, "2021-5"], ["2021-02-03T00:00:00", 600400, "2021-5"], ["2021-02-02T00:00:00", 606400, "2021-5"], ["2021-02-01T00:00:00", 593900, "2021-5"], ["2021-01-29T00:00:00", 682500, "2021-4"], ["2021-01-28T00:00:00", 437200, "2021-4"], ["2021-01-27T00:00:00", 683300, "2021-4"], ["2021-01-26T00:00:00", 469900, "2021-4"], ["2021-01-25T00:00:00", 824300, "2021-4"], ["2021-01-22T00:00:00", 878700, "2021-3"], ["2021-01-21T00:00:00", 755200, "2021-3"], ["2021-01-20T00:00:00", 634500, "2021-3"], ["2021-01-19T00:00:00", 700700, "2021-3"], ["2021-01-18T00:00:00", 850100, "2021-3"], ["2021-01-15T00:00:00", 752000, "2021-2"], ["2021-01-14T00:00:00", 749700, "2021-2"], ["2021-01-13T00:00:00", 623100, "2021-2"], ["2021-01-12T00:00:00", 633500, "2021-2"], ["2021-01-11T00:00:00", 786900, "2021-2"], ["2021-01-08T00:00:00", 739800, "2021-1"], ["2021-01-07T00:00:00", 616000, "2021-1"], ["2021-01-06T00:00:00", 635000, "2021-1"], ["2021-01-05T00:00:00", 653500, "2021-1"], ["2021-01-04T00:00:00", 792100, "2021-1"], ["2020-12-31T00:00:00", 628120, "2020-53"], ["2020-12-30T00:00:00", 564770, "2020-53"], ["2020-12-29T00:00:00", 637610, "2020-53"], ["2020-12-28T00:00:00", 611380, "2020-53"], ["2020-12-25T00:00:00", 874910, "2020-52"], ["2020-12-24T00:00:00", 523500, "2020-52"], ["2020-12-23T00:00:00", 529610, "2020-52"], ["2020-12-22T00:00:00", 517670, "2020-52"], ["2020-12-21T00:00:00", 652430, "2020-52"], ["2020-12-18T00:00:00", 832310, "2020-51"], ["2020-12-17T00:00:00", 590300, "2020-51"], ["2020-12-16T00:00:00", 530890, "2020-51"], ["2020-12-15T00:00:00", 948860, "2020-51"], ["2020-12-14T00:00:00", 722460, "2020-51"], ["2020-12-11T00:00:00", 721710, "2020-50"], ["2020-12-10T00:00:00", 655870, "2020-50"], ["2020-12-09T00:00:00", 683020, "2020-50"], ["2020-12-08T00:00:00", 522530, "2020-50"], ["2020-12-07T00:00:00", 483840, "2020-50"], ["2020-12-04T00:00:00", 496960, "2020-49"], ["2020-12-03T00:00:00", 448840, "2020-49"], ["2020-12-02T00:00:00", 612480, "2020-49"], ["2020-12-01T00:00:00", 558190, "2020-49"], ["2020-11-30T00:00:00", 636680, "2020-49"], ["2020-11-27T00:00:00", 406570, "2020-48"], ["2020-11-26T00:00:00", 599050, "2020-48"], ["2020-11-25T00:00:00", 617760, "2020-48"], ["2020-11-24T00:00:00", 403970, "2020-48"], ["2020-11-23T00:00:00", 447160, "2020-48"], ["2020-11-20T00:00:00", 829730, "2020-47"], ["2020-11-19T00:00:00", 666610, "2020-47"], ["2020-11-18T00:00:00", 761020, "2020-47"], ["2020-11-17T00:00:00", 633100, "2020-47"], ["2020-11-16T00:00:00", 673890, "2020-47"], ["2020-11-13T00:00:00", 491700, "2020-46"], ["2020- ...
