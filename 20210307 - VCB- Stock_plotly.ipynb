# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_vcb.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df['Week_no']= df['datetime'].dt.week
df['Year_no']= df['datetime'].dt.year
df['Period'] = df['Year_no'].astype(str) + str("-") + df['Week_no'].astype(str)
df.tail(3)
# Out:
# <ipython-input-2-dfcbf00d03b2>:4: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#           <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# <Ticker>
# VCB           20090702      20.8013      20.9761     20.1021       20.2769
# VCB           20090701      22.0249      22.0249     20.8013       21.1509
# VCB           20090630      20.9761      20.9761     20.9761       20.9761
#
#           <Volume>  <Open>  <High>  <Low>  <Close>  <VolumeDeal>  <VolumeFB>  \
# <Ticker>
# VCB        1515670    59.5    60.0   57.5     58.0         40000       55180
# VCB        6248390    63.0    63.0   59.5     60.5       3410000      590680
# VCB         294070    60.0    60.0   60.0     60.0             0        4100
#
#           <VolumeFS>   datetime  Week_no  Year_no   Period
# <Ticker>
# VCB           104850 2009-07-02       27     2009  2009-27
# VCB           420000 2009-07-01       27     2009  2009-27
# VCB                0 2009-06-30       27     2009  2009-27

# %%
df =df[['<Close>','datetime','<Volume>','Period','Year_no']]
df = df.head(900)

# %%
#plot linechart for VCB price
short_rolling = df['<Close>'].rolling(window=20).mean()

ema_long = df['<Close>'].ewm(span=50, adjust=False).mean()
ema_short = df['<Close>'].ewm(span=20, adjust=False).mean()
line_price = df['<Close>']
fig = go.Figure()
#px.line(df_hpg, x='datetime', y='<Close>', labels={'x':'Date', 'y':'Price'})

fig.add_trace(go.Scatter(x=df.datetime, y=line_price, 
                        mode='lines', name='VCB'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_short, 
                        mode='lines', name='Span 20-days EMA'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_long, 
                        mode='lines', name='Span 50-days EMA'))
# Out:
# <div>                            <div id="f437f439-b5b8-4dc3-baef-053ba3038fa5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f437f439-b5b8-4dc3-baef-053ba3038fa5")) {                    Plotly.newPlot(                        "f437f439-b5b8-4dc3-baef-053ba3038fa5",                        [{"mode": "lines", "name": "VCB", "type": "scatter", "x": ["2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-19T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-05T00:00:00", "2021-02-04T00:00:00", "2021-02-03T00:00:00", "2021-02-02T00:00:00", "2021-02-01T00:00:00", "2021-01-29T00:00:00", "2021-01-28T00:00:00", "2021-01-27T00:00:00", "2021-01-26T00:00:00", "2021-01-25T00:00:00", "2021-01-22T00:00:00", "2021-01-21T00:00:00", "2021-01-20T00:00:00", "2021-01-19T00:00:00", "2021-01-18T00:00:00", "2021-01-15T00:00:00", "2021-01-14T00:00:00", "2021-01-13T00:00:00", "2021-01-12T00:00:00", "2021-01-11T00:00:00", "2021-01-08T00:00:00", "2021-01-07T00:00:00", "2021-01-06T00:00:00", "2021-01-05T00:00:00", "2021-01-04T00:00:00", "2020-12-31T00:00:00", "2020-12-30T00:00:00", "2020-12-29T00:00:00", "2020-12-28T00:00:00", "2020-12-25T00:00:00", "2020-12-24T00:00:00", "2020-12-23T00:00:00", "2020-12-22T00:00:00", "2020-12-21T00:00:00", "2020-12-18T00:00:00", "2020-12-17T00:00:00", "2020-12-16T00:00:00", "2020-12-15T00:00:00", "2020-12-14T00:00:00", "2020-12-11T00:00:00", "2020-12-10T00:00:00", "2020-12-09T00:00:00", "2020-12-08T00:00:00", "2020-12-07T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-20T00:00:00", "2020-11-19T00:00:00", "2020-11-18T00:00:00", "2020-11-17T00:00:00", "2020-11-16T00:00:00", "2020-11-13T00:00:00", "2020-11-12T00:00:00", "2020-11-11T00:00:00", "2020-11-10T00:00:00", "2020-11-09T00:00:00", "2020-11-06T00:00:00", "2020-11-05T00:00:00", "2020-11-04T00:00:00", "2020-11-03T00:00:00", "2020-11-02T00:00:00", "2020-10-30T00:00:00", "2020-10-29T00:00:00", "2020-10-28T00:00:00", "2020-10-27T00:00:00", "2020-10-26T00:00:00", "2020-10-23T00:00:00", "2020-10-22T00:00:00", "2020-10-21T00:00:00", "2020-10-20T00:00:00", "2020-10-19T00:00:00", "2020-10-16T00:00:00", "2020-10-15T00:00:00", "2020-10-14T00:00:00", "2020-10-13T00:00:00", "2020-10-12T00:00:00", "2020-10-09T00:00:00", "2020-10-08T00:00:00", "2020-10-07T00:00:00", "2020-10-06T00:00:00", "2020-10-05T00:00:00", "2020-10-02T00:00:00", "2020-10-01T00:00:00", "2020-09-30T00:00:00", "2020-09-29T00:00:00", "2020-09-28T00:00:00", "2020-09-25T00:00:00", "2020-09-24T00:00:00", "2020-09-23T00:00:00", "2020-09-22T00:00:00", "2020-09-21T00:00:00", "2020-09-18T00:00:00", "2020-09-17T00:00:00", "2020-09-16T00:00:00", "2020-09-15T00:00:00", "2020-09-14T00:00:00", "2020-09-11T00:00:00", "2020-09-10T00:00:00", "2020-09-09T00:00:00", "2020-09-08T00:00:00", "2020-09-07T00:00:00", "2020-09-04T00:00:00", "2020-09-03T00:00:00", "2020-09-01T00:00:00", "2020-08-31T00:00:00", "2020-08-28T00:00:00", "2020-08-27T00:00:00", "2020-08-26T00:00:00", "2020-08-25T00:00:00", "2020-08-24T00:00:00", "2020-08-21T00:00:00", "2020-08-20T00:00:00", "2020-08-19T00:00:00", "2020-08-18T00:00:00", "2020-08-17T00:00:00", "2020-08-14T00:00:00", "2020-08-13T00:00:00", "2020-08-12T00:00:00", "2020-08-11T00:00:00", "2020-08-10T00:00:00", "2020-08-07T00:00:00", "2020-08-06T00:00:00", "2020-08-05T00:00:00", "2020-08-04T00:00:00", "2020-08-03T00:00:00", "2020-0 ...

# %%
#px.violin(df_tips, y="tip", x="smoker", color="sex", box=True, points="all",
#          hover_data=df_tips.columns)

fig = go.Figure()
px.violin(df,x='Year_no',y='<Close>',box =True, points='all',
         hover_data=df.columns, title = 'VCB Violin chart')
# Out:
# <div>                            <div id="307855b0-b72b-497b-b305-5ff67af6294c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("307855b0-b72b-497b-b305-5ff67af6294c")) {                    Plotly.newPlot(                        "307855b0-b72b-497b-b305-5ff67af6294c",                        [{"alignmentgroup": "True", "box": {"visible": true}, "customdata": [["2021-03-05T00:00:00", 1661600, "2021-9"], ["2021-03-04T00:00:00", 1118100, "2021-9"], ["2021-03-03T00:00:00", 915600, "2021-9"], ["2021-03-02T00:00:00", 1189600, "2021-9"], ["2021-03-01T00:00:00", 911200, "2021-9"], ["2021-02-26T00:00:00", 1070700, "2021-8"], ["2021-02-25T00:00:00", 896100, "2021-8"], ["2021-02-24T00:00:00", 1265300, "2021-8"], ["2021-02-23T00:00:00", 1441400, "2021-8"], ["2021-02-22T00:00:00", 1388700, "2021-8"], ["2021-02-19T00:00:00", 1851200, "2021-7"], ["2021-02-18T00:00:00", 1688900, "2021-7"], ["2021-02-17T00:00:00", 1054100, "2021-7"], ["2021-02-09T00:00:00", 2978900, "2021-6"], ["2021-02-08T00:00:00", 2902200, "2021-6"], ["2021-02-05T00:00:00", 897400, "2021-5"], ["2021-02-04T00:00:00", 967300, "2021-5"], ["2021-02-03T00:00:00", 1454600, "2021-5"], ["2021-02-02T00:00:00", 1064500, "2021-5"], ["2021-02-01T00:00:00", 1309600, "2021-5"], ["2021-01-29T00:00:00", 1359000, "2021-4"], ["2021-01-28T00:00:00", 1205500, "2021-4"], ["2021-01-27T00:00:00", 1566800, "2021-4"], ["2021-01-26T00:00:00", 970500, "2021-4"], ["2021-01-25T00:00:00", 725900, "2021-4"], ["2021-01-22T00:00:00", 1268500, "2021-3"], ["2021-01-21T00:00:00", 1283700, "2021-3"], ["2021-01-20T00:00:00", 2093000, "2021-3"], ["2021-01-19T00:00:00", 1130300, "2021-3"], ["2021-01-18T00:00:00", 1060400, "2021-3"], ["2021-01-15T00:00:00", 1099800, "2021-2"], ["2021-01-14T00:00:00", 832200, "2021-2"], ["2021-01-13T00:00:00", 1064200, "2021-2"], ["2021-01-12T00:00:00", 634900, "2021-2"], ["2021-01-11T00:00:00", 847400, "2021-2"], ["2021-01-08T00:00:00", 963900, "2021-1"], ["2021-01-07T00:00:00", 889000, "2021-1"], ["2021-01-06T00:00:00", 2080400, "2021-1"], ["2021-01-05T00:00:00", 739200, "2021-1"], ["2021-01-04T00:00:00", 855900, "2021-1"], ["2020-12-31T00:00:00", 367140, "2020-53"], ["2020-12-30T00:00:00", 509510, "2020-53"], ["2020-12-29T00:00:00", 696510, "2020-53"], ["2020-12-28T00:00:00", 836090, "2020-53"], ["2020-12-25T00:00:00", 314960, "2020-52"], ["2020-12-24T00:00:00", 815730, "2020-52"], ["2020-12-23T00:00:00", 666390, "2020-52"], ["2020-12-22T00:00:00", 748840, "2020-52"], ["2020-12-21T00:00:00", 697030, "2020-52"], ["2020-12-18T00:00:00", 1053200, "2020-51"], ["2020-12-17T00:00:00", 2305960, "2020-51"], ["2020-12-16T00:00:00", 740700, "2020-51"], ["2020-12-15T00:00:00", 1433260, "2020-51"], ["2020-12-14T00:00:00", 931080, "2020-51"], ["2020-12-11T00:00:00", 776190, "2020-50"], ["2020-12-10T00:00:00", 1299820, "2020-50"], ["2020-12-09T00:00:00", 1198160, "2020-50"], ["2020-12-08T00:00:00", 702820, "2020-50"], ["2020-12-07T00:00:00", 945460, "2020-50"], ["2020-12-04T00:00:00", 860900, "2020-49"], ["2020-12-03T00:00:00", 736760, "2020-49"], ["2020-12-02T00:00:00", 746710, "2020-49"], ["2020-12-01T00:00:00", 1162270, "2020-49"], ["2020-11-30T00:00:00", 1448340, "2020-49"], ["2020-11-27T00:00:00", 1210580, "2020-48"], ["2020-11-26T00:00:00", 698350, "2020-48"], ["2020-11-25T00:00:00", 1088020, "2020-48"], ["2020-11-24T00:00:00", 996580, "2020-48"], ["2020-11-23T00:00:00", 648830, "2020-48"], ["2020-11-20T00:00:00", 1231960, "2020-47"], ["2020-11-19T00:00:00", 2584440, "2020-47"], ["2020-11-18T00:00:00", 906810, "2020-47"], ["2020-11-17T00:00:00", 548250, "2020-47"], ["2020-11-16T00:00:00", 1250340, "2020-47"], ["2020-11-13T00:00:00", 417840, "2020-46"], ["2020-11-12T00:00:00", 405350, "2020-46"], ["2020-11-11T00:00:00", 1032520, "2020-46"], ["2020-11-10T0 ...
