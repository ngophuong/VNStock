# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_gas.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df['Week_no']= df['datetime'].dt.week
df['Year_no']= df['datetime'].dt.year
df['Period'] = df['Year_no'].astype(str) + str("-") + df['Week_no'].astype(str)
df.tail(3)
# Out:
#           <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# <Ticker>
# GAS           20120523      27.1568      27.2201     25.8907       25.8908
# GAS           20120522      27.2202      27.2202     26.9036       27.2201
# GAS           20120521      23.4220      26.0174     23.4220       25.9541
#
#           <Volume>  <Open>  <High>  <Low>  <Close>  <VolumeDeal>  <VolumeFB>  \
# <Ticker>
# GAS        1055780    42.9    43.0   40.9     40.9             0      721600
# GAS        1934550    43.0    43.0   42.5     43.0       2900000      901340
# GAS        2502080    37.0    41.1   37.0     41.0             0     1355080
#
#           <VolumeFS>   datetime  Week_no  Year_no   Period
# <Ticker>
# GAS                0 2012-05-23       21     2012  2012-21
# GAS           200000 2012-05-22       21     2012  2012-21
# GAS                0 2012-05-21       21     2012  2012-21

# %%
df =df[['<Close>','datetime','<Volume>','Period','Year_no']]
df = df.head(900)

# %%
#plot linechart for HPG price
short_rolling = df['<Close>'].rolling(window=20).mean()

ema_long = df['<Close>'].ewm(span=50, adjust=False).mean()
ema_short = df['<Close>'].ewm(span=20, adjust=False).mean()
line_price = df['<Close>']
fig = go.Figure()
#px.line(df_hpg, x='datetime', y='<Close>', labels={'x':'Date', 'y':'Price'})

fig.add_trace(go.Scatter(x=df.datetime, y=line_price, 
                        mode='lines', name='GAS'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_short, 
                        mode='lines', name='Span 20-days EMA'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_long, 
                        mode='lines', name='Span 50-days EMA'))
# Out:
# <div>                            <div id="547de398-f4ef-4738-844d-830b912c308a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("547de398-f4ef-4738-844d-830b912c308a")) {                    Plotly.newPlot(                        "547de398-f4ef-4738-844d-830b912c308a",                        [{"mode": "lines", "name": "GAS", "type": "scatter", "x": ["2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-19T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-05T00:00:00", "2021-02-04T00:00:00", "2021-02-03T00:00:00", "2021-02-02T00:00:00", "2021-02-01T00:00:00", "2021-01-29T00:00:00", "2021-01-28T00:00:00", "2021-01-27T00:00:00", "2021-01-26T00:00:00", "2021-01-25T00:00:00", "2021-01-22T00:00:00", "2021-01-21T00:00:00", "2021-01-20T00:00:00", "2021-01-19T00:00:00", "2021-01-18T00:00:00", "2021-01-15T00:00:00", "2021-01-14T00:00:00", "2021-01-13T00:00:00", "2021-01-12T00:00:00", "2021-01-11T00:00:00", "2021-01-08T00:00:00", "2021-01-07T00:00:00", "2021-01-06T00:00:00", "2021-01-05T00:00:00", "2021-01-04T00:00:00", "2020-12-31T00:00:00", "2020-12-30T00:00:00", "2020-12-29T00:00:00", "2020-12-28T00:00:00", "2020-12-25T00:00:00", "2020-12-24T00:00:00", "2020-12-23T00:00:00", "2020-12-22T00:00:00", "2020-12-21T00:00:00", "2020-12-18T00:00:00", "2020-12-17T00:00:00", "2020-12-16T00:00:00", "2020-12-15T00:00:00", "2020-12-14T00:00:00", "2020-12-11T00:00:00", "2020-12-10T00:00:00", "2020-12-09T00:00:00", "2020-12-08T00:00:00", "2020-12-07T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-20T00:00:00", "2020-11-19T00:00:00", "2020-11-18T00:00:00", "2020-11-17T00:00:00", "2020-11-16T00:00:00", "2020-11-13T00:00:00", "2020-11-12T00:00:00", "2020-11-11T00:00:00", "2020-11-10T00:00:00", "2020-11-09T00:00:00", "2020-11-06T00:00:00", "2020-11-05T00:00:00", "2020-11-04T00:00:00", "2020-11-03T00:00:00", "2020-11-02T00:00:00", "2020-10-30T00:00:00", "2020-10-29T00:00:00", "2020-10-28T00:00:00", "2020-10-27T00:00:00", "2020-10-26T00:00:00", "2020-10-23T00:00:00", "2020-10-22T00:00:00", "2020-10-21T00:00:00", "2020-10-20T00:00:00", "2020-10-19T00:00:00", "2020-10-16T00:00:00", "2020-10-15T00:00:00", "2020-10-14T00:00:00", "2020-10-13T00:00:00", "2020-10-12T00:00:00", "2020-10-09T00:00:00", "2020-10-08T00:00:00", "2020-10-07T00:00:00", "2020-10-06T00:00:00", "2020-10-05T00:00:00", "2020-10-02T00:00:00", "2020-10-01T00:00:00", "2020-09-30T00:00:00", "2020-09-29T00:00:00", "2020-09-28T00:00:00", "2020-09-25T00:00:00", "2020-09-24T00:00:00", "2020-09-23T00:00:00", "2020-09-22T00:00:00", "2020-09-21T00:00:00", "2020-09-18T00:00:00", "2020-09-17T00:00:00", "2020-09-16T00:00:00", "2020-09-15T00:00:00", "2020-09-14T00:00:00", "2020-09-11T00:00:00", "2020-09-10T00:00:00", "2020-09-09T00:00:00", "2020-09-08T00:00:00", "2020-09-07T00:00:00", "2020-09-04T00:00:00", "2020-09-03T00:00:00", "2020-09-01T00:00:00", "2020-08-31T00:00:00", "2020-08-28T00:00:00", "2020-08-27T00:00:00", "2020-08-26T00:00:00", "2020-08-25T00:00:00", "2020-08-24T00:00:00", "2020-08-21T00:00:00", "2020-08-20T00:00:00", "2020-08-19T00:00:00", "2020-08-18T00:00:00", "2020-08-17T00:00:00", "2020-08-14T00:00:00", "2020-08-13T00:00:00", "2020-08-12T00:00:00", "2020-08-11T00:00:00", "2020-08-10T00:00:00", "2020-08-07T00:00:00", "2020-08-06T00:00:00", "2020-08-05T00:00:00", "2020-08-04T00:00:00", "2020-08-03T00:00:00", "2020-0 ...

# %%
#px.violin(df_tips, y="tip", x="smoker", color="sex", box=True, points="all",
#          hover_data=df_tips.columns)

fig = go.Figure()
px.violin(df,x='Year_no',y='<Close>',box =True, points='all',
         hover_data=df.columns, title = 'GAS Violin chart')
# Out:
# <div>                            <div id="07c20559-a49b-4b98-9408-e411c3b07f6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07c20559-a49b-4b98-9408-e411c3b07f6a")) {                    Plotly.newPlot(                        "07c20559-a49b-4b98-9408-e411c3b07f6a",                        [{"alignmentgroup": "True", "box": {"visible": true}, "customdata": [["2021-03-05T00:00:00", 1469200, "2021-9"], ["2021-03-04T00:00:00", 1325100, "2021-9"], ["2021-03-03T00:00:00", 696900, "2021-9"], ["2021-03-02T00:00:00", 1386700, "2021-9"], ["2021-03-01T00:00:00", 1661100, "2021-9"], ["2021-02-26T00:00:00", 872900, "2021-8"], ["2021-02-25T00:00:00", 1366000, "2021-8"], ["2021-02-24T00:00:00", 820100, "2021-8"], ["2021-02-23T00:00:00", 1546200, "2021-8"], ["2021-02-22T00:00:00", 1156500, "2021-8"], ["2021-02-19T00:00:00", 1134700, "2021-7"], ["2021-02-18T00:00:00", 2259700, "2021-7"], ["2021-02-17T00:00:00", 1923100, "2021-7"], ["2021-02-09T00:00:00", 1216500, "2021-6"], ["2021-02-08T00:00:00", 1695100, "2021-6"], ["2021-02-05T00:00:00", 799000, "2021-5"], ["2021-02-04T00:00:00", 790800, "2021-5"], ["2021-02-03T00:00:00", 874500, "2021-5"], ["2021-02-02T00:00:00", 934100, "2021-5"], ["2021-02-01T00:00:00", 670300, "2021-5"], ["2021-01-29T00:00:00", 902600, "2021-4"], ["2021-01-28T00:00:00", 1569900, "2021-4"], ["2021-01-27T00:00:00", 940900, "2021-4"], ["2021-01-26T00:00:00", 1329100, "2021-4"], ["2021-01-25T00:00:00", 1225400, "2021-4"], ["2021-01-22T00:00:00", 1062200, "2021-3"], ["2021-01-21T00:00:00", 966400, "2021-3"], ["2021-01-20T00:00:00", 1022600, "2021-3"], ["2021-01-19T00:00:00", 1158400, "2021-3"], ["2021-01-18T00:00:00", 972000, "2021-3"], ["2021-01-15T00:00:00", 1767000, "2021-2"], ["2021-01-14T00:00:00", 775000, "2021-2"], ["2021-01-13T00:00:00", 1091600, "2021-2"], ["2021-01-12T00:00:00", 949100, "2021-2"], ["2021-01-11T00:00:00", 743600, "2021-2"], ["2021-01-08T00:00:00", 934700, "2021-1"], ["2021-01-07T00:00:00", 1446600, "2021-1"], ["2021-01-06T00:00:00", 1161900, "2021-1"], ["2021-01-05T00:00:00", 1262700, "2021-1"], ["2021-01-04T00:00:00", 1362600, "2021-1"], ["2020-12-31T00:00:00", 957350, "2020-53"], ["2020-12-30T00:00:00", 672840, "2020-53"], ["2020-12-29T00:00:00", 490820, "2020-53"], ["2020-12-28T00:00:00", 2377030, "2020-53"], ["2020-12-25T00:00:00", 617310, "2020-52"], ["2020-12-24T00:00:00", 1253120, "2020-52"], ["2020-12-23T00:00:00", 551200, "2020-52"], ["2020-12-22T00:00:00", 909760, "2020-52"], ["2020-12-21T00:00:00", 1296520, "2020-52"], ["2020-12-18T00:00:00", 590630, "2020-51"], ["2020-12-17T00:00:00", 1844030, "2020-51"], ["2020-12-16T00:00:00", 773810, "2020-51"], ["2020-12-15T00:00:00", 1095430, "2020-51"], ["2020-12-14T00:00:00", 860080, "2020-51"], ["2020-12-11T00:00:00", 914520, "2020-50"], ["2020-12-10T00:00:00", 1085890, "2020-50"], ["2020-12-09T00:00:00", 1135190, "2020-50"], ["2020-12-08T00:00:00", 1140540, "2020-50"], ["2020-12-07T00:00:00", 1390120, "2020-50"], ["2020-12-04T00:00:00", 1502870, "2020-49"], ["2020-12-03T00:00:00", 978850, "2020-49"], ["2020-12-02T00:00:00", 983710, "2020-49"], ["2020-12-01T00:00:00", 1332900, "2020-49"], ["2020-11-30T00:00:00", 1332670, "2020-49"], ["2020-11-27T00:00:00", 947930, "2020-48"], ["2020-11-26T00:00:00", 1099520, "2020-48"], ["2020-11-25T00:00:00", 1428530, "2020-48"], ["2020-11-24T00:00:00", 1824250, "2020-48"], ["2020-11-23T00:00:00", 1796080, "2020-48"], ["2020-11-20T00:00:00", 1207780, "2020-47"], ["2020-11-19T00:00:00", 2283360, "2020-47"], ["2020-11-18T00:00:00", 3450740, "2020-47"], ["2020-11-17T00:00:00", 2192600, "2020-47"], ["2020-11-16T00:00:00", 1255550, "2020-47"], ["2020-11-13T00:00:00", 896800, "2020-46"], ["2020-11-12T00:00:00", 547590, "2020-46"], ["2020-11-11T00:00:00", 1594170, "2020-46"], ["2020- ...
