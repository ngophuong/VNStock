# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_vix.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df['Week_no']= df['datetime'].dt.week
df['Year_no']= df['datetime'].dt.year
df['Period'] = df['Year_no'].astype(str) + str("-") + df['Week_no'].astype(str)
df.head(3)
# Out:
#           <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# <Ticker>
# VIX           20210310         37.5        37.55       35.65         36.00
# VIX           20210309         40.2        40.25       37.40         37.55
# VIX           20210308         40.3        41.00       39.85         40.20
#
#           <Volume>  <Open>  <High>  <Low>  <Close>  <VolumeDeal>  <VolumeFB>  \
# <Ticker>
# VIX        6086300    37.5   37.55  35.65    36.00             0        5000
# VIX        7942400    40.2   40.25  37.40    37.55             0        5600
# VIX        8958000    40.3   41.00  39.85    40.20             0         500
#
#           <VolumeFS>   datetime  Week_no  Year_no   Period
# <Ticker>
# VIX             7500 2021-03-10       10     2021  2021-10
# VIX             2000 2021-03-09       10     2021  2021-10
# VIX            11300 2021-03-08       10     2021  2021-10

# %%
df =df[['<Close>','datetime','<Volume>','Period','Year_no']]
df = df.head(900)

# %%
#plot linechart for HPG price
short_rolling = df['<Close>'].rolling(window=20).mean()

ema_long = df['<Close>'].ewm(span=50, adjust=False).mean()
ema_short = df['<Close>'].ewm(span=20, adjust=False).mean()
line_price = df['<Close>']
fig = go.Figure()
#px.line(df_hpg, x='datetime', y='<Close>', labels={'x':'Date', 'y':'Price'})

fig.add_trace(go.Scatter(x=df.datetime, y=line_price, 
                        mode='lines', name='VIX'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_short, 
                        mode='lines', name='Span 20-days EMA'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_long, 
                        mode='lines', name='Span 50-days EMA'))
# Out:
# <div>                            <div id="10a0f20e-99c8-4533-b207-d807f91438d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10a0f20e-99c8-4533-b207-d807f91438d5")) {                    Plotly.newPlot(                        "10a0f20e-99c8-4533-b207-d807f91438d5",                        [{"mode": "lines", "name": "VIX", "type": "scatter", "x": ["2021-03-10T00:00:00", "2021-03-09T00:00:00", "2021-03-08T00:00:00", "2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-19T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-05T00:00:00", "2021-02-04T00:00:00", "2021-02-03T00:00:00", "2021-02-02T00:00:00", "2021-02-01T00:00:00", "2021-01-29T00:00:00", "2021-01-28T00:00:00", "2021-01-27T00:00:00", "2021-01-26T00:00:00", "2021-01-25T00:00:00", "2021-01-22T00:00:00", "2021-01-21T00:00:00", "2021-01-20T00:00:00", "2021-01-19T00:00:00", "2021-01-18T00:00:00", "2021-01-15T00:00:00", "2021-01-14T00:00:00", "2021-01-13T00:00:00", "2021-01-12T00:00:00", "2021-01-11T00:00:00", "2021-01-08T00:00:00", "2020-12-28T00:00:00", "2020-12-25T00:00:00", "2020-12-24T00:00:00", "2020-12-23T00:00:00", "2020-12-22T00:00:00", "2020-12-21T00:00:00", "2020-12-18T00:00:00", "2020-12-17T00:00:00", "2020-12-16T00:00:00", "2020-12-15T00:00:00", "2020-12-14T00:00:00", "2020-12-11T00:00:00", "2020-12-10T00:00:00", "2020-12-09T00:00:00", "2020-12-08T00:00:00", "2020-12-07T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-20T00:00:00", "2020-11-19T00:00:00", "2020-11-18T00:00:00", "2020-11-17T00:00:00", "2020-11-16T00:00:00", "2020-11-13T00:00:00", "2020-11-12T00:00:00", "2020-11-11T00:00:00", "2020-11-10T00:00:00", "2020-11-09T00:00:00", "2020-11-06T00:00:00", "2020-11-05T00:00:00", "2020-11-04T00:00:00", "2020-11-03T00:00:00", "2020-11-02T00:00:00", "2020-10-30T00:00:00", "2020-10-29T00:00:00", "2020-10-28T00:00:00", "2020-10-27T00:00:00", "2020-10-26T00:00:00", "2020-10-23T00:00:00", "2020-10-22T00:00:00", "2020-10-21T00:00:00", "2020-10-20T00:00:00", "2020-10-19T00:00:00", "2020-10-16T00:00:00", "2020-10-15T00:00:00", "2020-10-14T00:00:00", "2020-10-13T00:00:00", "2020-10-12T00:00:00", "2020-10-09T00:00:00", "2020-10-08T00:00:00", "2020-10-07T00:00:00", "2020-10-06T00:00:00", "2020-10-05T00:00:00", "2020-10-02T00:00:00", "2020-10-01T00:00:00", "2020-09-30T00:00:00", "2020-09-29T00:00:00", "2020-09-28T00:00:00", "2020-09-25T00:00:00", "2020-09-24T00:00:00", "2020-09-23T00:00:00", "2020-09-22T00:00:00", "2020-09-21T00:00:00", "2020-09-18T00:00:00", "2020-09-17T00:00:00", "2020-09-16T00:00:00", "2020-09-15T00:00:00", "2020-09-14T00:00:00", "2020-09-11T00:00:00", "2020-09-10T00:00:00", "2020-09-09T00:00:00", "2020-09-08T00:00:00", "2020-09-07T00:00:00", "2020-09-04T00:00:00", "2020-09-03T00:00:00", "2020-09-01T00:00:00", "2020-08-31T00:00:00", "2020-08-28T00:00:00", "2020-08-27T00:00:00", "2020-08-26T00:00:00", "2020-08-25T00:00:00", "2020-08-24T00:00:00", "2020-08-21T00:00:00", "2020-08-20T00:00:00", "2020-08-19T00:00:00", "2020-08-18T00:00:00", "2020-08-17T00:00:00", "2020-08-14T00:00:00", "2020-08-13T00:00:00", "2020-08-12T00:00:00", "2020-08-11T00:00:00", "2020-08-10T00:00:00", "2020-08-07T00:00:00", "2020-08-06T00:00:00", "2020-08-05T00:00:00", "2020-08-04T00:00:00", "2020-08-03T00:00:00", "2020-07-31T00:00:00", "2020-07-30T00:00:00", "2020-07-29T00:00:00", "2020-07-28T00:00:00", "2020-0 ...

# %%
#px.violin(df_tips, y="tip", x="smoker", color="sex", box=True, points="all",
#          hover_data=df_tips.columns)

fig = go.Figure()
px.violin(df,x='Year_no',y='<Close>',box =True, points='all',
         hover_data=df.columns, title = 'VIX Violin chart')
# Out:
# <div>                            <div id="b047d761-dec9-4810-a1a4-f66fbce7b10a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b047d761-dec9-4810-a1a4-f66fbce7b10a")) {                    Plotly.newPlot(                        "b047d761-dec9-4810-a1a4-f66fbce7b10a",                        [{"alignmentgroup": "True", "box": {"visible": true}, "customdata": [["2021-03-10T00:00:00", 6086300, "2021-10"], ["2021-03-09T00:00:00", 7942400, "2021-10"], ["2021-03-08T00:00:00", 8958000, "2021-10"], ["2021-03-05T00:00:00", 8436100, "2021-9"], ["2021-03-04T00:00:00", 6189500, "2021-9"], ["2021-03-03T00:00:00", 8186500, "2021-9"], ["2021-03-02T00:00:00", 5252900, "2021-9"], ["2021-03-01T00:00:00", 4637500, "2021-9"], ["2021-02-26T00:00:00", 7261900, "2021-8"], ["2021-02-25T00:00:00", 5007600, "2021-8"], ["2021-02-24T00:00:00", 5647000, "2021-8"], ["2021-02-23T00:00:00", 7911200, "2021-8"], ["2021-02-22T00:00:00", 6571700, "2021-8"], ["2021-02-19T00:00:00", 6433800, "2021-7"], ["2021-02-18T00:00:00", 1920000, "2021-7"], ["2021-02-17T00:00:00", 1982400, "2021-7"], ["2021-02-09T00:00:00", 2844400, "2021-6"], ["2021-02-08T00:00:00", 3073900, "2021-6"], ["2021-02-05T00:00:00", 1692100, "2021-5"], ["2021-02-04T00:00:00", 2448200, "2021-5"], ["2021-02-03T00:00:00", 3050000, "2021-5"], ["2021-02-02T00:00:00", 3864300, "2021-5"], ["2021-02-01T00:00:00", 3911900, "2021-5"], ["2021-01-29T00:00:00", 2202500, "2021-4"], ["2021-01-28T00:00:00", 1943500, "2021-4"], ["2021-01-27T00:00:00", 3007400, "2021-4"], ["2021-01-26T00:00:00", 2428400, "2021-4"], ["2021-01-25T00:00:00", 3178300, "2021-4"], ["2021-01-22T00:00:00", 4398900, "2021-3"], ["2021-01-21T00:00:00", 3763100, "2021-3"], ["2021-01-20T00:00:00", 5723500, "2021-3"], ["2021-01-19T00:00:00", 5344700, "2021-3"], ["2021-01-18T00:00:00", 6137300, "2021-3"], ["2021-01-15T00:00:00", 5288100, "2021-2"], ["2021-01-14T00:00:00", 3526300, "2021-2"], ["2021-01-13T00:00:00", 3205600, "2021-2"], ["2021-01-12T00:00:00", 3057600, "2021-2"], ["2021-01-11T00:00:00", 3365300, "2021-2"], ["2021-01-08T00:00:00", 484900, "2021-1"], ["2020-12-28T00:00:00", 2873610, "2020-53"], ["2020-12-25T00:00:00", 3335399, "2020-52"], ["2020-12-24T00:00:00", 5878800, "2020-52"], ["2020-12-23T00:00:00", 3267893, "2020-52"], ["2020-12-22T00:00:00", 4538794, "2020-52"], ["2020-12-21T00:00:00", 5154005, "2020-52"], ["2020-12-18T00:00:00", 4593334, "2020-51"], ["2020-12-17T00:00:00", 3883120, "2020-51"], ["2020-12-16T00:00:00", 4331675, "2020-51"], ["2020-12-15T00:00:00", 5432469, "2020-51"], ["2020-12-14T00:00:00", 3987500, "2020-51"], ["2020-12-11T00:00:00", 3781679, "2020-50"], ["2020-12-10T00:00:00", 4931212, "2020-50"], ["2020-12-09T00:00:00", 4545371, "2020-50"], ["2020-12-08T00:00:00", 3122040, "2020-50"], ["2020-12-07T00:00:00", 4218435, "2020-50"], ["2020-12-04T00:00:00", 3850937, "2020-49"], ["2020-12-03T00:00:00", 5089559, "2020-49"], ["2020-12-02T00:00:00", 2721680, "2020-49"], ["2020-12-01T00:00:00", 3285378, "2020-49"], ["2020-11-30T00:00:00", 3515040, "2020-49"], ["2020-11-27T00:00:00", 2633215, "2020-48"], ["2020-11-26T00:00:00", 2926004, "2020-48"], ["2020-11-25T00:00:00", 4483229, "2020-48"], ["2020-11-24T00:00:00", 5832224, "2020-48"], ["2020-11-23T00:00:00", 6429600, "2020-48"], ["2020-11-20T00:00:00", 3772545, "2020-47"], ["2020-11-19T00:00:00", 4166980, "2020-47"], ["2020-11-18T00:00:00", 3338597, "2020-47"], ["2020-11-17T00:00:00", 3678014, "2020-47"], ["2020-11-16T00:00:00", 4578078, "2020-47"], ["2020-11-13T00:00:00", 2423270, "2020-46"], ["2020-11-12T00:00:00", 2092324, "2020-46"], ["2020-11-11T00:00:00", 1917301, "2020-46"], ["2020-11-10T00:00:00", 2470806, "2020-46"], ["2020-11-09T00:00:00", 2282527, "2020-46"], ["2020-11-06T00:00:00", 854707, "2020-45"], ["2020-11-05T00:00: ...
