# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_acv.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df['Week_no']= df['datetime'].dt.week
df['Year_no']= df['datetime'].dt.year
df['Period'] = df['Year_no'].astype(str) + str("-") + df['Week_no'].astype(str)
df.head(3)
# Out:
#           <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# <Ticker>
# ACV           20210310         75.1         75.8        64.5          75.2
# ACV           20210309         76.7         76.8        75.1          75.1
# ACV           20210308         77.0         78.0        76.5          76.6
#
#           <Volume>  <Open>  <High>  <Low>  <Close>  <VolumeDeal>  <VolumeFB>  \
# <Ticker>
# ACV         323216    75.1    75.8   64.5     75.2          1000      110000
# ACV         429100    76.7    76.8   75.1     75.1             0       47300
# ACV         252900    77.0    78.0   76.5     76.6             0       47300
#
#           <VolumeFS>   datetime  Week_no  Year_no   Period
# <Ticker>
# ACV           188200 2021-03-10       10     2021  2021-10
# ACV           126000 2021-03-09       10     2021  2021-10
# ACV           126000 2021-03-08       10     2021  2021-10

# %%
df =df[['<Close>','datetime','<Volume>','Period','Year_no']]
df = df.head(900)

# %%
#plot linechart for HPG price
short_rolling = df['<Close>'].rolling(window=20).mean()

ema_long = df['<Close>'].ewm(span=50, adjust=False).mean()
ema_short = df['<Close>'].ewm(span=20, adjust=False).mean()
line_price = df['<Close>']
fig = go.Figure()
#px.line(df_hpg, x='datetime', y='<Close>', labels={'x':'Date', 'y':'Price'})

fig.add_trace(go.Scatter(x=df.datetime, y=line_price, 
                        mode='lines', name='ACV'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_short, 
                        mode='lines', name='Span 20-days EMA'))

fig.add_trace(go.Scatter(x=df.datetime, y=ema_long, 
                        mode='lines', name='Span 50-days EMA'))
# Out:
# <div>                            <div id="9c3935b9-bc20-4a9a-9b5e-b97416ebed77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c3935b9-bc20-4a9a-9b5e-b97416ebed77")) {                    Plotly.newPlot(                        "9c3935b9-bc20-4a9a-9b5e-b97416ebed77",                        [{"mode": "lines", "name": "ACV", "type": "scatter", "x": ["2021-03-10T00:00:00", "2021-03-09T00:00:00", "2021-03-08T00:00:00", "2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-19T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-05T00:00:00", "2021-02-04T00:00:00", "2021-02
.1, 74.6, 73.3, 73.0, 73.2, 71.4, 72.0, 71.8, 72.3, 71.6, 70.9, 72.0, 74.1, 74.5, 73.9, 72.1, 72.0, 70.3, 68.6, 69.0, 68.2, 67.0, 65.9, 63.1, 63.0, 63.0, 63.1, 62.8, 62.6, 61.6, 61.7, 62.0, 63.5, 63.6, 63.5, 62.1, 62.0, 62.1, 62.5, 62.4, 61.8, 61.5]}, {"mode": "lines", "name": "Span 20-days EMA", "type": "scatter", "x": ["2021-03-10T00:00:00", "2021-03-09T00:00:00", "2021-03-08T00:00:00", "2021-03-05T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-26T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-19T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-05T00:00 ...

# %%
#px.violin(df_tips, y="tip", x="smoker", color="sex", box=True, points="all",
#          hover_data=df_tips.columns)

fig = go.Figure()
px.violin(df,x='Year_no',y='<Close>',box =True, points='all',
         hover_data=df.columns, title = 'ACV Violin chart')
# Out:
# <div>                            <div id="e44adbce-5a46-4874-80d3-10f7dd08a5ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e44adbce-5a46-4874-80d3-10f7dd08a5ac")) {                    Plotly.newPlot(                        "e44adbce-5a46-4874-80d3-10f7dd08a5ac",                        [{"alignmentgroup": "True", "box": {"visible": true}, "customdata": [["2021-03-10T00:00:00", 323216, "2021-10"], ["2021-03-09T00:00:00", 429100, "2021-10"], ["2021-03-08T00:00:00", 252900, "2021-10"], ["2021-03-05T00:00:00", 243441, "2021-9"], ["2021-03-04T00:00:00", 487987, "2021-9"], ["2021-03-03T00:00:00", 216300, "2021-9"], ["2021-03-02T00:00:00", 194169, "2021-9"], ["2021-03-01T00:00:00", 222949, "2021-9"], ["2021-02-26T00:00:00", 96800, "2021-8"], ["2021-02-25T00:00:00", 140477, "2021-8"], ["2021-02-24T00:00:00", 155242, "2021-8"], ["2021-02-23T00:00:00", 532716, "2021-8"], ["2021-02-22T00:00:00", 268680, "2021-8"], ["2021-02-19T00:00:00", 206300, "2021-7"], ["2021-02-18T00:00:00", 268000, "2021-7"], ["2021-02-17T00:00:00", 40439, "2021-7"], ["2021-02-09T00:00:00", 321234, "2021-6"], ["2021-02-08T00:00:00", 426200, "2021-6"], ["2021-02-05T00:00:00", 88607, "2021-5"], ["2021-02-04T00:00:00", 119827, "2021-5"], ["2021-02-03T00:00:00", 73721, "2021-5"], ["2021-02-02T00:00:00", 215997, "2021-5"], ["2021-02-01T00:00:00", 252000, "2021-5"], ["2021-01-29T00:00:00", 207733, "2021-4"], ["2021-01-