# %%
import mplfinance as mpf
import pandas as pd
import numpy as np
import matplotlib as mpl
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/ngophuong/VNStock/main/excel_fpt.csv'
df = pd.read_csv(url, index_col = 0)
df['datetime']=pd.to_datetime(df['<DTYYYYMMDD>'],format='%Y%m%d')
df.set_index('datetime',inplace = True)
df = df.sort_index(ascending = True)
df
# Out:
#             <DTYYYYMMDD>  <OpenFixed>  <HighFixed>  <LowFixed>  <CloseFixed>  \
# datetime
# 2006-12-13      20061213      22.5807      22.5807     22.5807       22.5807
# 2006-12-14      20061214      23.7097      23.7097     23.7097       23.7097
# 2006-12-15      20061215      24.8952      24.8952     24.8952       24.8952
# 2006-12-18      20061218      26.1371      26.1371     26.1371       26.1372
# 2006-12-19      20061219      27.4356      27.4356     27.4356       27.4356
# ...                  ...          ...          ...         ...           ...
# 2021-03-15      20210315      76.6000      77.5000     76.1000       76.5000
# 2021-03-16      20210316      77.0000      81.5000     76.6000       81.0000
# 2021-03-17      20210317      81.5000      81.5000     80.0000       80.8000
# 2021-03-18      20210318      81.0000      81.0000     80.0000       81.0000
# 2021-03-19      20210319      80.0000      80.5000     79.4000       79.8000
#
#             <Volume>  <Open>  <High>  <Low>  <Close>  <VolumeDeal>  \
# datetime
# 2006-12-13     83530   400.0   400.0  400.0    400.0             0
# 2006-12-14    280710   420.0   420.0  420.0    420.0             0
# 2006-12-15    265300   441.0   441.0  441.0    441.0             0
# 2006-12-18    215790   463.0   463.0  463.0    463.0             0
# 2006-12-19    137520   486.0   486.0  486.0    486.0             0
# ...              ...     ...     ...    ...      ...           ...
# 2021-03-15   1760900    76.6    77.5   76.1     76.5         40500
# 2021-03-16   5111000    77.0    81.5   76.6     81.0         60000
# 2021-03-17   1603200    81.5    81.5   80.0     80.8       1963800
# 2021-03-18   1807500    81.0    81.0   80.0     81.0        370000
# 2021-03-19   2247800    80.0    80.5   79.4     79.8        675700
#
#             <VolumeFB>  <VolumeFS>
# datetime
# 2006-12-13        1240           0
# 2006-12-14      178460           0
# 2006-12-15       61650       60000
# 2006-12-18      123310           0
# 2006-12-19       46450           0
# ...                ...         ...
# 2021-03-15           0           0
# 2021-03-16           0       15400
# 2021-03-17           0        5700
# 2021-03-18           0       40000
# 2021-03-19           0       53400
#
# [3551 rows x 13 columns]

# %%
df =df[['<OpenFixed>','<HighFixed>','<LowFixed>','<CloseFixed>','<Volume>']]
df = df.tail(200)

# %%
df = df.rename(columns={"<OpenFixed>": "Open", "<HighFixed>": "High",
                        "<LowFixed>":"Low","<CloseFixed>":"Close","<Volume>":"Volume"})
list(df.columns)
# Out:
# ['Open', 'High', 'Low', 'Close', 'Volume']

# %%
mpf.plot(df,type='candle',mav=(3,6,9),volume=True)
